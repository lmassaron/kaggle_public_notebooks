# %% [markdown]
# # **Introduction to EDA/Modelling for Multi-Class Prediction of Obesity Risk**

# %% [markdown]
# ![easy_peasy_EDA](https://th.bing.com/th/id/OIG4.Z3X2KIgpwXplIxzX6Z90?pid=ImgGn)

# %% [markdown]
# The notebook has the **Multiclass Classification with a Obesity Risk competition, Playground Season-4 Episode-2**, as object.

# %% [markdown]
# The notebook is structured as a series of cells and comments, from data exploration to building and optimizing a first starter model using XGBoost. By following it you can understabnd both the data problem and grasp the actions to be taken with similar tabular data problems.
#
# The approach is to explore data using the essential commands for tabular and chart representations. Often, on Kaggle Notebooks for competitions, EDA is weighted with tons of charts and plots that you cannot understand what they serve for, based on the principle "The More The Merrier". The idea is instead to just go to the point and show the relevant plots and keyt understanding in a dataset that could help you to devise the better strategies and feature engineering.
#
# The modelling part is also striving to just do the essential, hence you will find a single model devised to show how far you can go with the state of the art in tabular data modelling, i.e. XGBoost.

# %% [markdown]
# The notebook is arrange into six parts, with sections:
#
# 1. Data loading and first exploration
# 2. Target analysis
# 3. EDA and data preparation
# 4. Modelling
# 5. Explainability
# 6. Preparation of the submission

# %% [markdown]
# Most of the used approaches / code snippets can be found on the books:
#
# 1. The Kaggle Book by Konrad Banachewicz and Luca Massaron
# 2. The Kaggle Workbook by Konrad Banachewicz and Luca Massaron
# 3. Developing Kaggle Notebooks by Gabriel Preda
#
# for a wider discussion of the topics of EDA and modelling just refer to these books

# %% [markdown]
# ## 1.0 Data loading and first exploration

# %% [markdown]
# First, the basic Python packages (more will be loaded later, when needed)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load the data and set the id as index

# %%
train = pd.read_csv("/kaggle/input/playground-series-s4e2/train.csv").set_index("id")
test = pd.read_csv("/kaggle/input/playground-series-s4e2/test.csv").set_index("id")

# %%
train.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
train.head(5).T
# Out:
# id                                                  0              1  \
# Gender                                           Male         Female
# Age                                         24.443011           18.0
# Height                                       1.699998           1.56
# Weight                                       81.66995           57.0
# family_history_with_overweight                    yes            yes
# FAVC                                              yes            yes
# FCVC                                              2.0            2.0
# NCP                                          2.983297            3.0
# CAEC                                        Sometimes     Frequently
# SMOKE                                              no             no
# CH2O                                         2.763573            2.0
# SCC                                                no             no
# FAF                                               0.0            1.0
# TUE                                          0.976473            1.0
# CALC                                        Sometimes             no
# MTRANS                          Public_Transportation     Automobile
# NObeyesdad                        Overweight_Level_II  Normal_Weight
#
# id                                                  2                      3  \
# Gender                                         Female                 Female
# Age                                              18.0              20.952737
# Height                                        1.71146                1.71073
# Weight                                      50.165754             131.274851
# family_history_with_overweight                    yes                    yes
# FAVC                                              yes                    yes
# FCVC                                         1.880534                    3.0
# NCP                                          1.411685                    3.0
# CAEC                                        Sometimes              Sometimes
# SMOKE                                              no                     no
# CH2O                                         1.910378               1.674061
# SCC                                                no                     no
# FAF                                          0.866045               1.467863
# TUE                                          1.673584               0.780199
# CALC                                               no              Sometimes
# MTRANS                          Public_Transportation  Public_Transportation
# NObeyesdad                        Insufficient_Weight       Obesity_Type_III
#
# id                                                  4
# Gender                                           Male
# Age                                         31.641081
# Height                                       1.914186
# Weight                                      93.798055
# family_history_with_overweight                    yes
# FAVC                                              yes
# FCVC                                         2.679664
# NCP                                          1.971472
# CAEC                                        Sometimes
# SMOKE                                              no
# CH2O                                         1.979848
# SCC                                                no
# FAF                                          1.967973
# TUE                                          0.931721
# CALC                                        Sometimes
# MTRANS                          Public_Transportation
# NObeyesdad                        Overweight_Level_II

# %%
test.head(5).T
# Out:
# id                                              20758                  20759  \
# Gender                                           Male                 Female
# Age                                         26.899886                   21.0
# Height                                       1.848294                    1.6
# Weight                                     120.644178                   66.0
# family_history_with_overweight                    yes                    yes
# FAVC                                              yes                    yes
# FCVC                                         2.938616                    2.0
# NCP                                               3.0                    1.0
# CAEC                                        Sometimes              Sometimes
# SMOKE                                              no                     no
# CH2O                                         2.825629                    3.0
# SCC                                                no                     no
# FAF                                            0.8554                    1.0
# TUE                                               0.0                    0.0
# CALC                                        Sometimes              Sometimes
# MTRANS                          Public_Transportation  Public_Transportation
#
# id                                              20760                  20761  \
# Gender                                         Female                   Male
# Age                                              26.0              20.979254
# Height                                       1.643355               1.553127
# Weight                                     111.600553             103.669116
# family_history_with_overweight                    yes                    yes
# FAVC                                              yes                    yes
# FCVC                                              3.0                    2.0
# NCP                                               3.0               2.977909
# CAEC                                        Sometimes              Sometimes
# SMOKE                                              no                     no
# CH2O                                         2.621877               2.786417
# SCC                                                no                     no
# FAF                                               0.0               0.094851
# TUE                                          0.250502                    0.0
# CALC                                        Sometimes              Sometimes
# MTRANS                          Public_Transportation  Public_Transportation
#
# id                                              20762
# Gender                                         Female
# Age                                              26.0
# Height                                       1.627396
# Weight                                     104.835346
# family_history_with_overweight                    yes
# FAVC                                              yes
# FCVC                                              3.0
# NCP                                               3.0
# CAEC                                        Sometimes
# SMOKE                                              no
# CH2O                                         2.653531
# SCC                                                no
# FAF                                               0.0
# TUE                                          0.741069
# CALC                                        Sometimes
# MTRANS                          Public_Transportation

# %% [markdown]
# The dataset seems similar to "Obesity based on eating habits & physical cond" (https://www.kaggle.com/datasets/ankurbajaj9/obesity-levels) which has been derived from:
#
# Palechor, Fabio Mendoza, and Alexis de la Hoz Manotas. "Dataset for estimation of obesity levels based on eating habits and physical condition in individuals from Colombia, Peru and Mexico." Data in brief 25 (2019): 104344.
# (https://www.sciencedirect.com/science/article/pii/S2352340919306985)
#
# The research paper introduces a dataset designed for estimating obesity levels in individuals across Mexico, Peru, and Colombia. The estimation relies on factors such as eating habits and physical condition. The dataset encompasses 17 attributes and 2111 records, each labeled with the class variable NObesity (Obesity Level). This variable facilitates the classification of data into categories including Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II, and Obesity Type III.
#
# Of the total data, 77% was synthetically generated using the Weka tool and the SMOTE filter, while the remaining 23% was directly collected from users through a web platform. The dataset serves as a valuable resource for developing intelligent computational tools capable of identifying an individual's obesity level. Additionally, it can be utilized for constructing recommender systems aimed at monitoring and addressing obesity levels.

# %% [markdown]
# In particular we can deduct that:
# * 'Gender', 'Age', 'Height', 'Weight' are physical attributes
# * 'family_history_with_overweight' points out to familiarity with obesity
# * FAVC = Frequent consumption of high caloric food
# * FCVC = Frequency of consumption of vegetables
# * NCP = Number of main meals
# * CAEC = Consumption of food between meals
# * SMOKE = tobacco usage
# * CH20 = Consumption of water daily
# * SCC = Calories consumption monitoring
# * FAF = Physical activity frequency
# * TUE = Time using technology devices
# * CALC = Consumption of alcohol
# * MTRANS = Transportation used

# %% [markdown]
# The target is estracted from the train

# %%
target = train["NObeyesdad"]
train = train.drop("NObeyesdad", axis="columns")

# %% [markdown]
# ## 2.0 Target analysis

# %% [markdown]
# By examining the distribution of the target we can figure that:
#
# 1. it is a multiclass problem, with 7 class
# 2. the classes are distributed differently but there are not extreme differences in their proportions (expected probability)
# 3. However, the most frequent class (Obesity_Type_III) has almost the double of probability of the least frequent one (Overweight_Level_I), hence, when defining the cross-validation strategy when should consider a target stratified one thus such different prior probabilities will be reflected also in the test set as much exactly as possible.

# %%
target.value_counts()
# Out:
# NObeyesdad
# Obesity_Type_III       4046
# Obesity_Type_II        3248
# Normal_Weight          3082
# Obesity_Type_I         2910
# Insufficient_Weight    2523
# Overweight_Level_II    2522
# Overweight_Level_I     2427
# Name: count, dtype: int64

# %%
target.value_counts() / len(target)
# Out:
# NObeyesdad
# Obesity_Type_III       0.194913
# Obesity_Type_II        0.156470
# Normal_Weight          0.148473
# Obesity_Type_I         0.140187
# Insufficient_Weight    0.121544
# Overweight_Level_II    0.121495
# Overweight_Level_I     0.116919
# Name: count, dtype: float64

# %% [markdown]
# Here we represent the situation with a plot, ordering the classes based on overweight

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

color_list = ["#A5D7E8", "#576CBC", "#19376D", "#0B2447"]
cmap_custom = ListedColormap(color_list)

sorted_labels = ['Insufficient_Weight', 'Normal_Weight', 
 'Overweight_Level_I', 'Overweight_Level_II', 
 'Obesity_Type_I', 'Obesity_Type_II', 'Obesity_Type_III']

plt.figure(figsize=(8, 4))
ax = sns.countplot(x=target, order=sorted_labels, palette=color_list)

plt.title('Distribution of Obesity Risk Levels')
plt.xlabel('Obesity Risk Levels')
plt.ylabel('Count')

ax.set_xticklabels(ax.get_xticklabels(), rotation=10, ha='right', fontsize=8)
plt.tight_layout() 
plt.show()

# %% [markdown]
# for modelling purposes, we convert the target, expressed by string labels, into numeric labels, using a custom implementation of Scikit-learn LabelEncoder that orders the encoded label based on the order we proposed before.

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class CustomLabelEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, sorted_labels):
        self.classes_ = sorted_labels
        self.label_to_numeric_mapping = None

    def fit(self, y):
        self.label_to_numeric_mapping = {label: numeric for numeric, label in enumerate(self.classes_)}
        return self

    def transform(self, y):
        if self.label_to_numeric_mapping is None:
            raise ValueError("fit method must be called before transform")
        return y.map(self.label_to_numeric_mapping)

    def inverse_transform(self, y):
        if self.label_to_numeric_mapping is None:
            raise ValueError("fit method must be called before inverse_transform")
        return pd.Series(y).map({numeric: label for label, numeric in self.label_to_numeric_mapping.items()})

# %%
target_encoder = CustomLabelEncoder(sorted_labels)
target_encoder.fit(target)
target_numeric = target_encoder.transform(target)

# %%
target_numeric
# Out:
# id
# 0        3
# 1        1
# 2        0
# 3        6
# 4        3
#         ..
# 20753    5
# 20754    0
# 20755    5
# 20756    3
# 20757    5
# Name: NObeyesdad, Length: 20758, dtype: int64

# %% [markdown]
# Using our enconder, we can rever back from numeric to string anytime:

# %%
target_encoder.inverse_transform(target_numeric)
# Out:
# id
# 0        Overweight_Level_II
# 1              Normal_Weight
# 2        Insufficient_Weight
# 3           Obesity_Type_III
# 4        Overweight_Level_II
#                 ...
# 20753        Obesity_Type_II
# 20754    Insufficient_Weight
# 20755        Obesity_Type_II
# 20756    Overweight_Level_II
# 20757        Obesity_Type_II
# Name: NObeyesdad, Length: 20758, dtype: object

# %% [markdown]
# ## 3.0 EDA and data preparation

# %% [markdown]
# Let's proceed to indeep explore and prepare the datasets (both the train and the test in parallel) for being suitable for modelling with both GLMs and Tree-based models

# %% [markdown]
# ### 3.1 Missing values

# %% [markdown]
# Both train and test have no missing data

# %%
train.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# dtype: int64

# %% [markdown]
# ### 3.2 Data Types and feature classification

# %% [markdown]
# Let's enumerate the numeric (continuous and ordinal) features fromt the categorical ones

# %%
train.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# dtype: object

# %%
categorical_features = train.columns[train.dtypes=="object"].tolist()
numeric_features = train.columns[train.dtypes!="object"].tolist()

# %% [markdown]
# All the categorical features have very few unique levels, making one-hot-encoding the best choice for this situation

# %%
train[categorical_features].nunique()
# Out:
# Gender                            2
# family_history_with_overweight    2
# FAVC                              2
# CAEC                              4
# SMOKE                             2
# SCC                               2
# CALC                              3
# MTRANS                            5
# dtype: int64

# %% [markdown]
# All the numeric features, have enough distinct values to confirm their are continuous ones

# %%
train[numeric_features].nunique()
# Out:
# Age       1703
# Height    1833
# Weight    1979
# FCVC       934
# NCP        689
# CH2O      1506
# FAF       1360
# TUE       1297
# dtype: int64

# %% [markdown]
# ### 3.3 Plotting count and distribution pairs

# %%
def plot_count_pairs(train, test, feature, hue="set", order=None, palette=None):
    data_df = train.copy()
    data_df['set'] = 'train'
    data_df = pd.concat([data_df, test.copy()]).fillna('test')
    f, ax = plt.subplots(1, 1, figsize=(8, 4))
    sns.countplot(x=feature, data=data_df, hue=hue, palette=color_list, order=order)
    plt.grid(color="black", linestyle="-.", linewidth=0.5, axis="y", which="major")
    ax.set_title(f"Paired train/test frequencies of {feature}")
    plt.show()
    
for feature in categorical_features:
    if feature in ["CAEC", "CALC"]:
        order = ["no", "Always", "Sometimes", "Frequently"]
    else:
        order = sorted(train[feature].unique())
    plot_count_pairs(train, test, feature=feature, order=order, palette=color_list)

# %%
import warnings

def plot_distribution_pairs(train, test, feature, hue="set", palette=None):
    data_df = train.copy()
    data_df['set'] = 'train'
    data_df = pd.concat([data_df, test.copy()]).fillna('test')
    data_df.replace([np.inf, -np.inf], np.nan, inplace=True)

    f, ax = plt.subplots(1, 1, figsize=(8, 4))
    for i, s in enumerate(data_df[hue].unique()):
        selection = data_df.loc[data_df[hue]==s, feature]
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", category=FutureWarning)
            g = sns.histplot(selection, color=palette[i], ax=ax, label=s)
    ax.set_title(f"Paired train/test distributions of {feature}")
    g.legend()
    plt.show()

def plot_distribution_pairs_boxplot(train, test, feature, hue="set", palette=None):
    data_df = train.copy()
    data_df['set'] = 'train'
    data_df = pd.concat([data_df, test.copy()]).fillna('test')
    data_df.replace([np.inf, -np.inf], np.nan, inplace=True)

    f, ax = plt.subplots(1, 1, figsize=(8, 4))
    for i, s in enumerate(data_df[hue].unique()):
        selection = data_df.loc[data_df[hue]==s, feature]
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", category=FutureWarning)
            g = sns.boxplot(x=hue, y=feature, data=data_df, palette=palette, ax=ax)
    ax.set_title(f"Paired train/test boxplots of {feature}")
    g.legend()
    plt.show()
    
for feature in numeric_features:
    plot_distribution_pairs(train, test, feature, palette=color_list)
    plot_distribution_pairs_boxplot(train, test, feature, palette=color_list)

# %% [markdown]
# ### 3.4 Categorical encoding

# %% [markdown]
# We then proceed to process the categorical features by encoding them using the OneHotEncoder by Scikit-learn

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)
encoder.fit(pd.concat([train[categorical_features], test[categorical_features]], axis=0))

train_encoded = encoder.transform(train[categorical_features])
train_encoded_df = pd.DataFrame(train_encoded, columns=encoder.get_feature_names_out(categorical_features))

# %%
test_encoded = encoder.fit_transform(test[categorical_features])
test_encoded_df = pd.DataFrame(test_encoded, columns=encoder.get_feature_names_out(categorical_features))

# %%
train_sum = train_encoded_df.sum(axis=0).astype(int)
test_sum = test_encoded_df.sum(axis=0).astype(int)

sum_df = pd.concat([train_sum, test_sum], axis=1, keys=['Train', 'Test'])
sum_df
# Out:
#                                     Train   Test
# Gender_Female                       10422   6965
# Gender_Male                         10336   6875
# family_history_with_overweight_no    3744   2456
# family_history_with_overweight_yes  17014  11384
# FAVC_no                              1776   1257
# FAVC_yes                            18982  12583
# CAEC_Always                           478    359
# CAEC_Frequently                      2472   1617
# CAEC_Sometimes                      17529  11689
# CAEC_no                               279    175
# SMOKE_no                            20513  13660
# SMOKE_yes                             245    180
# SCC_no                              20071  13376
# SCC_yes                               687    464
# CALC_Always                             0      2
# CALC_Frequently                       529    346
# CALC_Sometimes                      15066   9979
# CALC_no                              5163   3513
# MTRANS_Automobile                    3534   2405
# MTRANS_Bike                            32     25
# MTRANS_Motorbike                       38     19
# MTRANS_Public_Transportation        16687  11111
# MTRANS_Walking                        467    280

# %% [markdown]
# ### 3.5 Adjusting categorical encodings

# %% [markdown]
# CALC_Always, being zero in training won't be used and there could be problems in the test if CALC is a relevant feature. We can then perform the combination of columns CALC_Always and CALC_Frequently in both train_encoded_df and test_encoded_df into a new column called 'CALC_Always|Frequently'. After creating the combined column, the original columns CALC_Always and CALC_Frequently are dropped.

# %%
combine_columns = ['CALC_Always', 'CALC_Frequently']

train_encoded_df['CALC_Always|Frequently'] = train_encoded_df[combine_columns].sum(axis=1)
test_encoded_df['CALC_Always|Frequently'] = test_encoded_df[combine_columns].sum(axis=1)

train_encoded_df = train_encoded_df.drop(columns=combine_columns).set_index(train.index)
test_encoded_df = test_encoded_df.drop(columns=combine_columns).set_index(test.index)

# %% [markdown]
# Before proceeding, let's also consider that CALC and CAEC are indeed ordinal features. We can replace them with an ordinal feature, too, to catch any linear effect due to these two features.

# %%
levels = {"Always": 3, "Frequently": 2, "Sometimes": 1, "no": 0}
train["CALC_ord"] = train["CALC"].map(levels)
test["CALC_ord"] = test["CALC"].map(levels)
train["CAEC_ord"] = train["CAEC"].map(levels)
test["CAEC_ord"] = test["CAEC"].map(levels)

# %% [markdown]
# Let's now integrate the categorical encodings in our original train and test datasets, replacing the previous categorical
# features

# %%
train = pd.concat([train.drop(categorical_features, axis=1), train_encoded_df], axis=1)
test = pd.concat([test.drop(categorical_features, axis=1), test_encoded_df], axis=1)

# %% [markdown]
# As a furthermore check before proceeding modelling, let's test adversarial validation between the train and the test datasets in order to be sure that they are from the same distribution and there is no particular shift between them. This will ensure us that we should expect the same target distribution too.

# %% [markdown]
# ### 3.6 Adversarial validation

# %% [markdown]
# We take the code for adversarial validation from the Kaggle Book: https://github.com/PacktPublishing/The-Kaggle-Book/blob/main/chapter_06/adversarial-validation-example.ipynb

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import roc_auc_score

X =  pd.concat([train, test], axis=0)
y = [0] * len(train) + [1] * len(test)

model = RandomForestClassifier(random_state=0)
cv_preds = cross_val_predict(model, X, y, cv=5, n_jobs=-1, method='predict_proba')

score = roc_auc_score(y_true=y, y_score=cv_preds[:,1])
print(f"roc-auc score: {score:0.3f}")
# Out:
# roc-auc score: 0.499

# %% [markdown]
# Since the roc-auc score is about 0.5, we have a confirmation that train and test are from the same distribution.

# %% [markdown]
# ### 3.7 Feature engineering

# %% [markdown]
# At this point we try to create some smart feature engineering. As a first step we calculate the Body Mass Index using the 'Height' and 'Weight' features. BMI is often used as an indicator of obesity and it better represents the relationship between weight and height.

# %%
train['BMI'] = train['Weight'] / (train['Height'] ** 2)
test['BMI'] = test['Weight'] / (test['Height'] ** 2)

# %%
plot_distribution_pairs(train, test, feature="BMI", palette=color_list)

# %% [markdown]
# We then combine 'FAF' (Physical activity frequency) with 'TUE' (Time using technology devices) to create a feature representing the balance between physical activity and sedentary behavior.

# %%
train['Physical_Activity_Level'] = train['FAF'] - train['TUE']
test['Physical_Activity_Level'] = test['FAF'] - test['TUE']

# %%
plot_distribution_pairs(train, test, feature="Physical_Activity_Level", palette=color_list)

# %% [markdown]
# Combine 'FCVC' (Frequency of consumption of vegetables) and 'NCP' (Number of main meals) to create a feature reflecting overall meal habits.

# %%
train['Meal_Habits'] = train['FCVC'] * train['NCP']
test['Meal_Habits'] = test['FCVC'] * test['NCP']

# %%
plot_distribution_pairs(train, test, feature="Meal_Habits", palette=color_list)

# %% [markdown]
# We also combine features like 'FCVC' (Frequency of consumption of vegetables) and 'FAVC' (Frequent consumption of high caloric food) to create a new feature representing overall nutrition habits.

# %%
(train['FAVC_yes'] - 2).unique
# Out:
# <bound method Series.unique of id
# 0       -1.0
# 1       -1.0
# 2       -1.0
# 3       -1.0
# 4       -1.0
#         ...
# 20753   -1.0
# 20754   -1.0
# 20755   -1.0
# 20756   -1.0
# 20757   -1.0
# Name: FAVC_yes, Length: 20758, dtype: float64>

# %%
train['Healthy_Nutrition_Habits'] = train['FCVC'] / ( 2 * train['FAVC_no'] - 1)
test['Healthy_Nutrition_Habits'] = test['FCVC'] / ( 2 * test['FAVC_no'] - 1)

# %%
plot_distribution_pairs(train, test, feature="Healthy_Nutrition_Habits", palette=color_list)

# %% [markdown]
# We finally create a score based on the frequency of technology usage ('TUE') weighted by the age: essentially, it quantifies the average amount of time a person spends using technology per unit of their age

# %%
train['Tech_Usage_Score'] = train['TUE'] / train['Age']
test['Tech_Usage_Score'] = test['TUE'] / test['Age']

# %%
plot_distribution_pairs(train, test, feature="Tech_Usage_Score", palette=color_list)

# %% [markdown]
# Since this completes our data preparation, we store the resulting transformed train and test datasets, hence we can reuse them in other Kaggle Notebooks.

# %%
train['Tech_Usage_Score'] = train['TUE'] / train['Age']
test['Tech_Usage_Score'] = test['TUE'] / test['Age']

# %%
train.to_csv("train.csv")
test.to_csv("test.csv")
target.to_csv("target.csv")

# %% [markdown]
# ## 4.0 Modelling

# %% [markdown]
# We can now proceed to modelling. First by defining our cv strategy, which is, as mentioned before, a stratified cross-validation based on the distribution of target labels.

# %%
from sklearn.model_selection import StratifiedKFold

cv = StratifiedKFold(5, shuffle=True, random_state=0)
cv_splits = cv.split(train, y=target_numeric)

# %%
list(cv_splits)
# Out:
# [(array([    0,     1,     2, ..., 20755, 20756, 20757]),
#   array([   15,    24,    27, ..., 20740, 20741, 20754])),
#  (array([    2,     3,     4, ..., 20755, 20756, 20757]),
#   array([    0,     1,     7, ..., 20748, 20750, 20752])),
#  (array([    0,     1,     2, ..., 20754, 20756, 20757]),
#   array([   10,    22,    23, ..., 20728, 20732, 20755])),
#  (array([    0,     1,     2, ..., 20752, 20754, 20755]),
#   array([    3,     4,     6, ..., 20753, 20756, 20757])),
#  (array([    0,     1,     3, ..., 20755, 20756, 20757]),
#   array([    2,     5,    14, ..., 20746, 20749, 20751]))]

# %% [markdown]
# ### 4.1 First temptative models (hand tuning)

# %% [markdown]
# XGBoost, by default, constructs an individual model for each target, a behavior reminiscent of meta-estimators in scikit-learn. This approach offers the advantage of efficient data reuse and leverages integrated features such as SHAP (SHapley Additive exPlanations). In the context of multi-label classification, XGBoost employs the binary relevance strategy. This strategy involves building separate binary classifiers for each class, treating the classification problem as a set of independent binary tasks. This allows the model to handle multi-label scenarios where each instance may belong to multiple classes.

# %%
# %%time

from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, accuracy_score
from xgboost import XGBClassifier

xgb = XGBClassifier(booster='gbtree',
                    device = "cuda",
                    tree_method="hist",
                    objective='multi:softmax',  # 'multi:softmax' for multiclass classification
                    num_class=len(set(target_numeric)),  # Number of classes
                    n_estimators=300,
                    max_depth=6,
                    verbosity=0)

cv_splits = cv.split(train, y=target_numeric)
scorer = make_scorer(accuracy_score)

cv_results = cross_validate(xgb, train, target_numeric, cv=cv_splits, scoring=scorer, return_train_score=False)

accuracy_mean = cv_results['test_score'].mean()
print(f'Cross-validated Accuracy: {accuracy_mean:.3f}')
# Out:
# Cross-validated Accuracy: 0.903
# CPU times: user 18.4 s, sys: 204 ms, total: 18.6 s
# Wall time: 17.3 s

# %% [markdown]
# One helpful step, after creating the first temptative model, is to do some error analysis and try to understand what is not working in the approach. To do so, we need to resort to cross_val_predict which will create a cross validated prediction useful to check the fit of the model.?

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict

cv_splits = cv.split(train, y=target_numeric)
cv_cls_preds = cross_val_predict(xgb, train, target_numeric, cv=cv_splits)

# %%
print(classification_report(y_true=target_numeric, y_pred=cv_cls_preds, target_names=target_encoder.classes_))
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.93      0.93      0.93      2523
#       Normal_Weight       0.87      0.88      0.88      3082
#  Overweight_Level_I       0.80      0.77      0.78      2427
# Overweight_Level_II       0.80      0.82      0.81      2522
#      Obesity_Type_I       0.89      0.88      0.88      2910
#     Obesity_Type_II       0.97      0.97      0.97      3248
#    Obesity_Type_III       1.00      1.00      1.00      4046
#
#            accuracy                           0.90     20758
#           macro avg       0.89      0.89      0.89     20758
#        weighted avg       0.90      0.90      0.90     20758

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_true=target_numeric, y_pred=cv_cls_preds)

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2) 
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=cmap_custom, 
            xticklabels=sorted_labels, yticklabels=sorted_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# From the overview of the error analysis, a step that always to be taken when working with tabular data, it seems that the decision boundaries between certain categories, in particular Overweight_Level_I and Overweight_Level_II, are not so well defined. In such cases it is helpful to use blended submissions between different but equally predictive models, to have better shaped class boundaries.

# %% [markdown]
# A solution, in our case, would be to blend our XGBoost with another gradient boosting solution, such as a LightGBM.

# %%
from lightgbm import LGBMClassifier

lgb = LGBMClassifier(boosting_type="gbdt",
                     objective="multiclass",
                     metric="multi_logloss",
                     num_class=7,
                     learning_rate=0.025,
                     n_estimators=500,
                     lambda_l1=0.06,
                     lambda_l2=0.3,
                     max_depth=9,
                     colsample_bytree=0.40,
                     subsample=0.85,
                     min_child_samples=15,
                     verbosity=-1)

cv_splits = cv.split(train, y=target_numeric)

cv_results = cross_validate(lgb, train, target_numeric, cv=cv_splits, scoring=scorer, return_train_score=False)

accuracy_mean = cv_results['test_score'].mean()
print(f'Cross-validated Accuracy: {accuracy_mean:.3f}')
# Out:
# /opt/conda/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# Cross-validated Accuracy: 0.909

# %%
cv_splits = cv.split(train, y=target_numeric)
cv_cls_lgb_preds = cross_val_predict(lgb, train, target_numeric, cv=cv_splits)

print(classification_report(y_true=target_numeric, y_pred=cv_cls_lgb_preds, target_names=target_encoder.classes_))

conf_matrix = confusion_matrix(y_true=target_numeric, y_pred=cv_cls_lgb_preds)

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2) 
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=cmap_custom, 
            xticklabels=sorted_labels, yticklabels=sorted_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

improvement = np.sum((cv_cls_lgb_preds==target_numeric)&(cv_cls_preds!=target_numeric)) / len(target_numeric)
print(f"maximum possible improvement: {improvement:0.3f}")
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.93      0.94      0.93      2523
#       Normal_Weight       0.88      0.89      0.89      3082
#  Overweight_Level_I       0.81      0.78      0.80      2427
# Overweight_Level_II       0.81      0.82      0.82      2522
#      Obesity_Type_I       0.89      0.89      0.89      2910
#     Obesity_Type_II       0.97      0.97      0.97      3248
#    Obesity_Type_III       1.00      1.00      1.00      4046
#
#            accuracy                           0.91     20758
#           macro avg       0.90      0.90      0.90     20758
#        weighted avg       0.91      0.91      0.91     20758
# maximum possible improvement: 0.017

# %% [markdown]
# training a LightGBM and doing some error analysis, does perform slightly better than XGBoost on the problematic classes. An estimation of possible maximum improvement considering only the correct estimates (not the erroneous ones) that a LightGBM could bring in a blend seems promising.

# %% [markdown]
# Before proceeding, however, let's test how the new multi output tree, which is especially designed for multiclass problem, could work.

# %% [markdown]
# As of XGBoost version 2.0, in fact, a new multi_strategy option has become available. the training parameter called multi_strategy allows you to specify how the model should handle multiple targets when constructing trees.
#
# By default, when multi_strategy is set to "one_output_per_tree" (which is the default), XGBoost builds one model for each target. Each model is trained independently for its corresponding target.
#
# Alternatively, when multi_strategy is set to "multi_output_tree," XGBoost constructs multi-output trees. In this mode, each leaf node of the tree is associated with all the targets, and the model learns to make joint predictions for multiple targets simultaneously. This allows to build a single, compact model.
#
# Since the multi_output_tree option is a work in progress, at the moment it only supports cpu as a device.

# %%
# %%time

xgb = XGBClassifier(booster='gbtree',
                    device = "cpu",
                    tree_method="hist",
                    multi_strategy="multi_output_tree", # for multi-output trees
                    objective='multi:softmax',  # 'multi:softmax' for multiclass classification
                    num_class=len(set(target_numeric)),  # Number of classes
                    n_estimators=300,
                    max_depth=6,
                    verbosity=0)

cv_splits = cv.split(train, y=target_numeric)

cv_results = cross_validate(xgb, train, target_numeric, cv=cv_splits, scoring=scorer, return_train_score=False)

accuracy_mean = cv_results['test_score'].mean()
print(f'Cross-validated Accuracy: {accuracy_mean:.3f}')
# Out:
# Cross-validated Accuracy: 0.901
# CPU times: user 2min 50s, sys: 350 ms, total: 2min 50s
# Wall time: 43.2 s

# %% [markdown]
# The solution is not bad, let's go for the faster binary relevance strategy, hence we can leverage the GPU, but let's consider the multi_output_strategy for a blended solution.

# %%
cv_splits = cv.split(train, y=target_numeric)
cv_cls_multi_preds = cross_val_predict(xgb, train, target_numeric, cv=cv_splits)

print(classification_report(y_true=target_numeric, y_pred=cv_cls_multi_preds, target_names=target_encoder.classes_))

conf_matrix = confusion_matrix(y_true=target_numeric, y_pred=cv_cls_multi_preds)

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2) 
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=cmap_custom, 
            xticklabels=sorted_labels, yticklabels=sorted_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.92      0.94      0.93      2523
#       Normal_Weight       0.87      0.88      0.87      3082
#  Overweight_Level_I       0.79      0.76      0.77      2427
# Overweight_Level_II       0.79      0.81      0.80      2522
#      Obesity_Type_I       0.89      0.88      0.88      2910
#     Obesity_Type_II       0.97      0.97      0.97      3248
#    Obesity_Type_III       1.00      1.00      1.00      4046
#
#            accuracy                           0.90     20758
#           macro avg       0.89      0.89      0.89     20758
#        weighted avg       0.90      0.90      0.90     20758

# %%
improvement = np.sum((cv_cls_multi_preds==target_numeric)&(cv_cls_preds!=target_numeric)) / len(target_numeric)
print(f"maximum possible improvement: {improvement:0.3f}")
# Out:
# maximum possible improvement: 0.013

# %% [markdown]
# ### 4.2 Approching the problem as a regression

# %% [markdown]
# Since the target is ordinal, we can test also operating using a regression instead of a classification

# %%
from xgboost import XGBRegressor

cv_splits = cv.split(train, y=target_numeric)
cv_scores = list()
cv_train_preds = np.zeros(len(train))
cv_test_preds = np.zeros(len(test))

for train_idx, val_idx in cv_splits:
    xgb = XGBRegressor(booster='gbtree',
                       device = "cpu",
                       tree_method="hist",
                       n_estimators=200,
                       max_depth=4,
                       verbosity=0)
    xgb.fit(train.iloc[train_idx], target_numeric.iloc[train_idx])
    preds = xgb.predict(train.iloc[val_idx])
    cv_train_preds[val_idx] = preds
    cv_test_preds += xgb.predict(test) / cv.n_splits
    cls_preds = np.clip(np.round(preds).astype(int), a_min=0, a_max=6)
    
    cv_scores.append(accuracy_score(y_true=target_numeric.iloc[val_idx], y_pred=cls_preds))

accuracy_mean = np.mean(cv_scores)
print(f'Cross-validated Accuracy: {accuracy_mean:.3f}')
# Out:
# Cross-validated Accuracy: 0.884

# %%
print(classification_report(y_true=target_numeric, 
                            y_pred=np.clip(np.round(cv_train_preds).astype(int), a_min=0, a_max=6), 
                            target_names=target_encoder.classes_))
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.92      0.92      0.92      2523
#       Normal_Weight       0.86      0.86      0.86      3082
#  Overweight_Level_I       0.76      0.74      0.75      2427
# Overweight_Level_II       0.74      0.78      0.76      2522
#      Obesity_Type_I       0.87      0.84      0.85      2910
#     Obesity_Type_II       0.96      0.96      0.96      3248
#    Obesity_Type_III       1.00      0.99      1.00      4046
#
#            accuracy                           0.88     20758
#           macro avg       0.87      0.87      0.87     20758
#        weighted avg       0.88      0.88      0.88     20758

# %% [markdown]
# The problems with this predictor are again the first two overweight categories, it tend to appear a weaker solution though, than using multiclass classification.

# %%
conf_matrix = confusion_matrix(y_true=target_numeric, 
                               y_pred=np.clip(np.round(cv_train_preds).astype(int), a_min=0, a_max=6))

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2) 
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=cmap_custom, 
            xticklabels=sorted_labels, yticklabels=sorted_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# The results from the regression are disappointing, but the regression's results could be improved and possibly be used as a feature for the classification.

# %% [markdown]
# ### 4.3 Model optimization by Optuna and Bayesian search

# %% [markdown]
# As a next step we optimize XGBoost most important hyper-parameters using a bayesian search by Optuna. The TPESampler is set to first try random optimization for the first 30 trials and then perform a TPE Bayesian Search. We also use the multivariate approach (added in v2.2.0 as an experimental feature), which is reported to outperform the independent TPE.

# %%
import optuna
from optuna.samplers import TPESampler

def objective(trial):
    
    params = {
        'grow_policy': trial.suggest_categorical('grow_policy', ["depthwise", "lossguide"]),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0, log=True),
        'gamma' : trial.suggest_float('gamma', 1e-9, 0.5),
        'subsample': trial.suggest_float('subsample', 0.3, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'max_depth': trial.suggest_int('max_depth', 0, 16),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-9, 100.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-9, 100.0, log=True),
        
    }
    
    params['booster'] = 'gbtree'
    params['objective'] = 'multi:softmax'
    params["device"] = "cuda"
    params["verbosity"] = 0
    params['tree_method'] = "hist"
    
    xgb = XGBClassifier(**params)
    cv_splits = cv.split(train, y=target_numeric)

    cv_scores = cross_validate(estimator=xgb, 
                               X=train, 
                               y=target_numeric,
                               scoring=scorer,
                               cv=cv_splits)

    cv_evaluation = np.mean(np.abs(cv_scores['test_score']))
    return cv_evaluation

sqlite_db = "sqlite:///sqlite.db"
study_name = "multi_class_prediction_of_obesity_risk"
study = optuna.create_study(storage=sqlite_db, study_name=study_name, 
                            sampler=TPESampler(n_startup_trials=30, multivariate=True, seed=0),
                            direction="maximize", load_if_exists=True)

study.optimize(objective, n_trials=150)
print(f"best optmized accuracy: {study.best_value:0.5f}")
print(f"best hyperparameters: {study.best_params}")

best_cls_params = study.best_params
best_cls_params['objective'] = 'multi:softmax'
best_cls_params['tree_method'] = "hist"
best_cls_params["device"] = "cuda"
best_cls_params["verbosity"] = 0
# Out:
# /opt/conda/lib/python3.10/site-packages/optuna/samplers/_tpe/sampler.py:319: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-02-26 08:03:44,895] A new study created in RDB with name: multi_class_prediction_of_obesity_risk
# [I 2024-02-26 08:04:29,835] Trial 0 finished with value: 0.904952587045209 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 643, 'learning_rate': 0.1229607110732571, 'gamma': 0.21182740024579755, 'subsample': 0.7521258791466592, 'colsample_bytree': 0.6063110478838847, 'max_depth': 15, 'min_child_weight': 7, 'reg_lambda': 1.65141683303417e-05, 'reg_alpha': 0.5116528751408895}. Best is trial 0 with value: 0.904952587045209.
# [I 2024-02-26 08:05:45,501] Trial 1 finished with value: 0.8991717528427117 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 933, 'learning_rate': 0.013869861245357327, 'gamma': 0.04356465076364105, 'subsample': 0.314152878208228, 'colsample_bytree': 0.8828338918835565, 'max_depth': 13, 'min_child_weight': 7, 'reg_lambda': 58.18375750787099, 'reg_alpha': 0.6176525039559425}. Best is trial 0 with value: 0.904952587045209.
# [I 2024-02-26 08:06:06,659] Trial 2 finished with value: 0.9053379899172332 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 206, 'learning_rate': 0.19047678084282033, 'gamma': 0.07167664456116991, 'subsample': 0.9612682419347087, 'colsample_bytree': 0.6652938252250502, 'max_depth': 7, 'min_child_weight': 2, 'reg_lambda': 0.32852663380525066, 'reg_alpha': 0.00010414865227627216}. Best is trial 2 with value: 0.9053379899172332.
# [I 2024-02-26 08:06:24,666] Trial 3 finished with value: 0.9053379667085816 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 656, 'learning_rate': 0.1675681386148849, 'gamma': 0.3084669988204445, 'subsample': 0.9606236549602369, 'colsample_bytree': 0.7772742093724383, 'max_depth': 6, 'min_child_weight': 4, 'reg_lambda': 0.04720012569807346, 'reg_alpha': 4.597060167257937e-09}. Best is trial 2 with value: 0.9053379899172332.
# [I 2024-02-26 08:06:57,776] Trial 4 finished with value: 0.903170220607519 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 289, 'learning_rate': 0.01810725406663109, 'gamma': 0.15771417614666358, 'subsample': 0.5545975396598358, 'colsample_bytree': 0.6991377392925158, 'max_depth': 7, 'min_child_weight': 7, 'reg_lambda': 1.3258454978412258e-08, 'reg_alpha': 1.984468990836302e-07}. Best is trial 2 with value: 0.9053379899172332.
# [I 2024-02-26 08:08:05,321] Trial 5 finished with value: 0.9058679594814073 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 328, 'learning_rate': 0.08562913278818232, 'gamma': 0.12221279675637577, 'subsample': 0.41127870855186377, 'colsample_bytree': 0.37726259881501356, 'max_depth': 11, 'min_child_weight': 1, 'reg_lambda': 1.4534696861865696e-07, 'reg_alpha': 1.1375667178247037e-05}. Best is trial 5 with value: 0.9058679594814073.
# [I 2024-02-26 08:09:12,703] Trial 6 finished with value: 0.9065423216728424 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 854, 'learning_rate': 0.015566709318481201, 'gamma': 0.48822973253023844, 'subsample': 0.6280558411533911, 'colsample_bytree': 0.9837327617332359, 'max_depth': 10, 'min_child_weight': 6, 'reg_lambda': 2.698147668840317e-09, 'reg_alpha': 1.2908524053225875e-06}. Best is trial 6 with value: 0.9065423216728424.
# [I 2024-02-26 08:09:48,339] Trial 7 finished with value: 0.9073132434601501 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 206, 'learning_rate': 0.04324803290528771, 'gamma': 0.20713149784307197, 'subsample': 0.344903247444149, 'colsample_bytree': 0.7847304835590139, 'max_depth': 9, 'min_child_weight': 2, 'reg_lambda': 0.0005698080600548553, 'reg_alpha': 1.0798057066618543e-08}. Best is trial 7 with value: 0.9073132434601501.
# [I 2024-02-26 08:10:01,557] Trial 8 finished with value: 0.9075057940399255 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 387, 'learning_rate': 0.21618261203953767, 'gamma': 0.06589893207039822, 'subsample': 0.8014290428829958, 'colsample_bytree': 0.5025842650630408, 'max_depth': 3, 'min_child_weight': 5, 'reg_lambda': 1.6641137462565914e-09, 'reg_alpha': 1.3132285667307797}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:10:09,605] Trial 9 finished with value: 0.8866464844230493 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 343, 'learning_rate': 0.2953847324956156, 'gamma': 0.4810942725965306, 'subsample': 0.4741272004639706, 'colsample_bytree': 0.7033101340924858, 'max_depth': 10, 'min_child_weight': 5, 'reg_lambda': 2.8437928571268845e-07, 'reg_alpha': 30.216149925077563}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:11:21,772] Trial 10 finished with value: 0.9062533507491055 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 730, 'learning_rate': 0.03934358239750428, 'gamma': 0.4068989100374408, 'subsample': 0.5775540185928892, 'colsample_bytree': 0.9167722379778132, 'max_depth': 9, 'min_child_weight': 7, 'reg_lambda': 0.04148083507630754, 'reg_alpha': 0.09501607319417765}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:12:32,983] Trial 11 finished with value: 0.9059642985950875 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 680, 'learning_rate': 0.07042228249480469, 'gamma': 0.303196607457569, 'subsample': 0.31343523881653346, 'colsample_bytree': 0.5111023716721845, 'max_depth': 11, 'min_child_weight': 3, 'reg_lambda': 0.006283038472173934, 'reg_alpha': 5.205419209355085e-05}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:13:05,808] Trial 12 finished with value: 0.904374447924195 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 613, 'learning_rate': 0.15196568166072377, 'gamma': 0.2871626248504642, 'subsample': 0.7572405738999934, 'colsample_bytree': 0.7564722890011821, 'max_depth': 7, 'min_child_weight': 7, 'reg_lambda': 1.1045377680557845e-05, 'reg_alpha': 6.230374866988627e-05}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:13:24,765] Trial 13 finished with value: 0.8911747708957936 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 734, 'learning_rate': 0.015865500409725952, 'gamma': 0.45974130695285415, 'subsample': 0.799968909684378, 'colsample_bytree': 0.9991929045975065, 'max_depth': 2, 'min_child_weight': 7, 'reg_lambda': 6.129460934261786e-08, 'reg_alpha': 0.005904120425153587}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:13:42,456] Trial 14 finished with value: 0.8784568590617484 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 827, 'learning_rate': 0.13746795663394853, 'gamma': 0.20359164920581652, 'subsample': 0.3484168968185966, 'colsample_bytree': 0.7882001412011945, 'max_depth': 7, 'min_child_weight': 6, 'reg_lambda': 3.390045952933395, 'reg_alpha': 53.79433646805575}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:13:56,020] Trial 15 finished with value: 0.9050007914150269 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 424, 'learning_rate': 0.28839061611017947, 'gamma': 0.08581483945909057, 'subsample': 0.6647256243428905, 'colsample_bytree': 0.33803659183747753, 'max_depth': 3, 'min_child_weight': 1, 'reg_lambda': 0.5378667984990456, 'reg_alpha': 2.9051701194597073e-07}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:14:31,427] Trial 16 finished with value: 0.9013878309611769 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 734, 'learning_rate': 0.011579181437349274, 'gamma': 0.08234707908426221, 'subsample': 0.7350348810498344, 'colsample_bytree': 0.7040600120229172, 'max_depth': 4, 'min_child_weight': 7, 'reg_lambda': 0.005670554327645104, 'reg_alpha': 0.0007797597849357062}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:15:34,094] Trial 17 finished with value: 0.904133553722691 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 381, 'learning_rate': 0.06258094608554399, 'gamma': 0.10492187527771732, 'subsample': 0.4303351041162353, 'colsample_bytree': 0.9610606729887534, 'max_depth': 12, 'min_child_weight': 4, 'reg_lambda': 3.1736637236578537e-07, 'reg_alpha': 6.279445557448057e-07}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:15:41,606] Trial 18 finished with value: 0.8986418877174709 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 380, 'learning_rate': 0.24699432654084996, 'gamma': 0.1888759202684886, 'subsample': 0.4257225742917443, 'colsample_bytree': 0.31727510987393187, 'max_depth': 1, 'min_child_weight': 5, 'reg_lambda': 9.787353852692122e-05, 'reg_alpha': 0.0007986772652469727}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:15:59,916] Trial 19 finished with value: 0.9028809827842862 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 295, 'learning_rate': 0.21191241762223467, 'gamma': 0.13166118910525293, 'subsample': 0.31445569962601005, 'colsample_bytree': 0.830865057685299, 'max_depth': 5, 'min_child_weight': 3, 'reg_lambda': 0.0029613398379436493, 'reg_alpha': 1.385265465982393}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:16:11,281] Trial 20 finished with value: 0.9030736610116465 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 346, 'learning_rate': 0.39454238706680056, 'gamma': 0.09281797296734015, 'subsample': 0.966954159880361, 'colsample_bytree': 0.7812417934714706, 'max_depth': 3, 'min_child_weight': 7, 'reg_lambda': 0.10949993830194632, 'reg_alpha': 6.213811414598653e-07}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:16:17,673] Trial 21 finished with value: 0.8846231773665514 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 123, 'learning_rate': 0.025998012658801462, 'gamma': 0.21234273495106765, 'subsample': 0.5619189862339579, 'colsample_bytree': 0.6245027970553674, 'max_depth': 4, 'min_child_weight': 5, 'reg_lambda': 3.179886838347125, 'reg_alpha': 1.9626841514325678e-08}. Best is trial 8 with value: 0.9075057940399255.
# [I 2024-02-26 08:16:57,654] Trial 22 finished with value: 0.9083247229235104 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 745, 'learning_rate': 0.06196114086045525, 'gamma': 0.2827106563638332, 'subsample': 0.428295885349855, 'colsample_bytree': 0.40139343154036405, 'max_depth': 8, 'min_child_weight': 3, 'reg_lambda': 22.118282352673155, 'reg_alpha': 0.26216685961913294}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:17:03,863] Trial 23 finished with value: 0.8985455718124425 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 175, 'learning_rate': 0.1271700786387963, 'gamma': 0.2922380348934084, 'subsample': 0.9733554649830602, 'colsample_bytree': 0.5045032687547841, 'max_depth': 4, 'min_child_weight': 1, 'reg_lambda': 1.5160932895785125e-09, 'reg_alpha': 16.781179571884028}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:18:07,500] Trial 24 finished with value: 0.9050970609027515 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 353, 'learning_rate': 0.14887450564652188, 'gamma': 0.0319776339965353, 'subsample': 0.639939317154236, 'colsample_bytree': 0.9842465978211128, 'max_depth': 14, 'min_child_weight': 3, 'reg_lambda': 37.78084786252428, 'reg_alpha': 3.537674663168283e-07}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:18:33,790] Trial 25 finished with value: 0.9032182973297518 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 820, 'learning_rate': 0.18234584582547816, 'gamma': 0.43714398343818556, 'subsample': 0.5051141991554577, 'colsample_bytree': 0.8942604887190426, 'max_depth': 10, 'min_child_weight': 1, 'reg_lambda': 6.600376315999144e-06, 'reg_alpha': 4.261372220556026e-08}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:18:51,099] Trial 26 finished with value: 0.903122016237701 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 548, 'learning_rate': 0.19008376820188855, 'gamma': 0.18429230369622415, 'subsample': 0.3958301901799192, 'colsample_bytree': 0.8754824132359718, 'max_depth': 3, 'min_child_weight': 4, 'reg_lambda': 2.9341838253549057e-07, 'reg_alpha': 1.1920358845879303e-08}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:19:18,880] Trial 27 finished with value: 0.8942095806243036 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 965, 'learning_rate': 0.650295873908924, 'gamma': 0.3870236665752721, 'subsample': 0.5332016064200493, 'colsample_bytree': 0.3567709729915977, 'max_depth': 6, 'min_child_weight': 2, 'reg_lambda': 2.8665794445349387e-08, 'reg_alpha': 3.869893378060102e-09}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:19:50,240] Trial 28 finished with value: 0.9044227915459236 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 794, 'learning_rate': 0.0196740282564536, 'gamma': 0.03976104221385579, 'subsample': 0.36272212396702375, 'colsample_bytree': 0.77043346514774, 'max_depth': 4, 'min_child_weight': 3, 'reg_lambda': 0.0013522491108884658, 'reg_alpha': 2.924576002707688}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:20:14,561] Trial 29 finished with value: 0.9028330801269421 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 218, 'learning_rate': 0.012904721633073907, 'gamma': 0.1507993179388726, 'subsample': 0.48348270446777475, 'colsample_bytree': 0.6192983967603357, 'max_depth': 11, 'min_child_weight': 5, 'reg_lambda': 1.3143387506888102e-06, 'reg_alpha': 1.5107636083968512e-05}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:20:55,645] Trial 30 finished with value: 0.900472296064416 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 542, 'learning_rate': 0.35031908616717533, 'gamma': 0.043291854568690294, 'subsample': 0.8089315227916305, 'colsample_bytree': 0.4366704176063138, 'max_depth': 0, 'min_child_weight': 4, 'reg_lambda': 6.643669080833601e-09, 'reg_alpha': 0.0002669571448041093}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:21:17,796] Trial 31 finished with value: 0.9016287367670068 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 864, 'learning_rate': 0.03537798745049238, 'gamma': 0.3245529589964339, 'subsample': 0.5047351673451065, 'colsample_bytree': 0.3932810156702059, 'max_depth': 2, 'min_child_weight': 3, 'reg_lambda': 3.645689046790152, 'reg_alpha': 0.15316993161795428}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:22:16,038] Trial 32 finished with value: 0.9068795665923526 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 911, 'learning_rate': 0.027985000816367005, 'gamma': 0.49741838161969304, 'subsample': 0.54244543322331, 'colsample_bytree': 0.8603812537512179, 'max_depth': 9, 'min_child_weight': 5, 'reg_lambda': 1.3144505019515014e-08, 'reg_alpha': 4.172746919096095e-08}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:22:39,819] Trial 33 finished with value: 0.903507453922703 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 124, 'learning_rate': 0.11155106629537132, 'gamma': 0.17951972784555895, 'subsample': 0.32965976052512513, 'colsample_bytree': 0.6775487908528188, 'max_depth': 10, 'min_child_weight': 2, 'reg_lambda': 0.0004984533955558086, 'reg_alpha': 6.9909957225605875e-09}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:22:56,744] Trial 34 finished with value: 0.8851048149133227 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 759, 'learning_rate': 0.1368657079742484, 'gamma': 0.2679244798660933, 'subsample': 0.3975584440924489, 'colsample_bytree': 0.46741420828509345, 'max_depth': 12, 'min_child_weight': 3, 'reg_lambda': 0.3878026497338929, 'reg_alpha': 39.02767020914922}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:23:05,563] Trial 35 finished with value: 0.8730614277312754 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 415, 'learning_rate': 0.28849015402681194, 'gamma': 0.06539703250015369, 'subsample': 0.8770856632387315, 'colsample_bytree': 0.5259519681411327, 'max_depth': 2, 'min_child_weight': 7, 'reg_lambda': 8.581019710182467e-07, 'reg_alpha': 77.68740870555638}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:23:55,216] Trial 36 finished with value: 0.9078912317249273 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 899, 'learning_rate': 0.015403503224282071, 'gamma': 0.43080921791742516, 'subsample': 0.48824940538761524, 'colsample_bytree': 0.6957093259329598, 'max_depth': 6, 'min_child_weight': 3, 'reg_lambda': 2.2257890016948502e-07, 'reg_alpha': 1.0486625932164102e-08}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:25:10,053] Trial 37 finished with value: 0.9079394012817674 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 809, 'learning_rate': 0.012887436142941964, 'gamma': 0.3151975502187828, 'subsample': 0.39883047183373277, 'colsample_bytree': 0.712998650581467, 'max_depth': 10, 'min_child_weight': 2, 'reg_lambda': 5.442509418127748e-08, 'reg_alpha': 3.063859271562998e-07}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:26:20,669] Trial 38 finished with value: 0.908180341900575 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 802, 'learning_rate': 0.020397003078046125, 'gamma': 0.40594694366195283, 'subsample': 0.33113324152077617, 'colsample_bytree': 0.4808368235735482, 'max_depth': 12, 'min_child_weight': 2, 'reg_lambda': 1.731781360634139e-08, 'reg_alpha': 4.516214334579465e-05}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:27:36,050] Trial 39 finished with value: 0.9080357287911218 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 794, 'learning_rate': 0.021133370328915227, 'gamma': 0.2924830753551816, 'subsample': 0.501013107519838, 'colsample_bytree': 0.4753940528924643, 'max_depth': 12, 'min_child_weight': 2, 'reg_lambda': 1.1319664627413417e-06, 'reg_alpha': 2.3296996520417727e-05}. Best is trial 22 with value: 0.9083247229235104.
# [I 2024-02-26 08:28:57,641] Trial 40 finished with value: 0.9085657331682734 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 746, 'learning_rate': 0.01345782302182156, 'gamma': 0.33457854283780974, 'subsample': 0.45880886580156627, 'colsample_bytree': 0.4266667292179257, 'max_depth': 12, 'min_child_weight': 1, 'reg_lambda': 6.743385262085545e-05, 'reg_alpha': 0.12712289103233498}. Best is trial 40 with value: 0.9085657331682734.
# [I 2024-02-26 08:30:12,571] Trial 41 finished with value: 0.9093365040993442 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 736, 'learning_rate': 0.014108481992583346, 'gamma': 0.356199034014881, 'subsample': 0.42081951746643403, 'colsample_bytree': 0.4336344900599051, 'max_depth': 15, 'min_child_weight': 4, 'reg_lambda': 6.404509342437434e-09, 'reg_alpha': 0.0019726949666361783}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:31:37,076] Trial 42 finished with value: 0.9089993404101154 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 933, 'learning_rate': 0.010025885401491628, 'gamma': 0.4150294097449436, 'subsample': 0.3618767902742825, 'colsample_bytree': 0.4781771068788538, 'max_depth': 14, 'min_child_weight': 5, 'reg_lambda': 4.529446203948765e-08, 'reg_alpha': 0.010469281260259448}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:32:31,766] Trial 43 finished with value: 0.9085175868200851 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 780, 'learning_rate': 0.01581684463801543, 'gamma': 0.4931630183417376, 'subsample': 0.3851856455526905, 'colsample_bytree': 0.30373595746841614, 'max_depth': 14, 'min_child_weight': 5, 'reg_lambda': 6.570263795982186e-06, 'reg_alpha': 0.5772356371643016}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:33:25,347] Trial 44 finished with value: 0.9074576941090406 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 778, 'learning_rate': 0.03394981577498811, 'gamma': 0.3628026082321988, 'subsample': 0.38199416052083157, 'colsample_bytree': 0.3368118134637503, 'max_depth': 13, 'min_child_weight': 6, 'reg_lambda': 8.681193679701727e-07, 'reg_alpha': 0.14925878589759156}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:34:25,347] Trial 45 finished with value: 0.9062533739577574 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 966, 'learning_rate': 0.04546833382461745, 'gamma': 0.4813289336974218, 'subsample': 0.3576385307490424, 'colsample_bytree': 0.6038439184768681, 'max_depth': 14, 'min_child_weight': 5, 'reg_lambda': 5.579132858081005e-08, 'reg_alpha': 0.00021232679986105444}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:35:06,625] Trial 46 finished with value: 0.8971966617603577 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 779, 'learning_rate': 0.01109520658808506, 'gamma': 0.43251162103149293, 'subsample': 0.4804407220661241, 'colsample_bytree': 0.4622648587766002, 'max_depth': 13, 'min_child_weight': 2, 'reg_lambda': 0.02040994520946267, 'reg_alpha': 11.588642160665431}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:37:12,495] Trial 47 finished with value: 0.9083729388976541 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 883, 'learning_rate': 0.01698921214697498, 'gamma': 0.410442781013263, 'subsample': 0.5173493326431373, 'colsample_bytree': 0.6384317888823399, 'max_depth': 13, 'min_child_weight': 7, 'reg_lambda': 2.4371407837543753e-07, 'reg_alpha': 0.03157820424986824}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:39:07,005] Trial 48 finished with value: 0.9083248505710954 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 912, 'learning_rate': 0.021289199332087803, 'gamma': 0.46761664397254904, 'subsample': 0.5518228923667615, 'colsample_bytree': 0.6541758806380013, 'max_depth': 13, 'min_child_weight': 7, 'reg_lambda': 2.5337296568277206e-08, 'reg_alpha': 0.03207727144918435}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:39:45,084] Trial 49 finished with value: 0.9066388696643889 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 327, 'learning_rate': 0.015351037128329154, 'gamma': 0.4394309689096465, 'subsample': 0.6265571379204802, 'colsample_bytree': 0.5145949171281567, 'max_depth': 15, 'min_child_weight': 3, 'reg_lambda': 8.325447807080382e-09, 'reg_alpha': 0.4034951436415655}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:40:58,893] Trial 50 finished with value: 0.9050008494366564 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 663, 'learning_rate': 0.010028492321453301, 'gamma': 0.4815585470406004, 'subsample': 0.5084212122586218, 'colsample_bytree': 0.32376897502834234, 'max_depth': 14, 'min_child_weight': 4, 'reg_lambda': 4.177486727084819e-08, 'reg_alpha': 1.8994465206262208}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:42:51,002] Trial 51 finished with value: 0.9091438258719841 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 872, 'learning_rate': 0.01415661760965567, 'gamma': 0.328339533557587, 'subsample': 0.5800765515362855, 'colsample_bytree': 0.7304247637161829, 'max_depth': 9, 'min_child_weight': 7, 'reg_lambda': 7.283274649687145e-09, 'reg_alpha': 0.00013665750728629277}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:45:38,915] Trial 52 finished with value: 0.9083729737106317 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 903, 'learning_rate': 0.01121910724476466, 'gamma': 0.1731836565572169, 'subsample': 0.5888423343055723, 'colsample_bytree': 0.6467250668144794, 'max_depth': 12, 'min_child_weight': 7, 'reg_lambda': 4.022367088550481e-08, 'reg_alpha': 0.00401812992307631}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:46:08,495] Trial 53 finished with value: 0.8974375791705136 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 874, 'learning_rate': 0.011041419686311066, 'gamma': 0.29341514553309694, 'subsample': 0.4360799726416988, 'colsample_bytree': 0.5206819593685125, 'max_depth': 3, 'min_child_weight': 7, 'reg_lambda': 8.722391907234554e-09, 'reg_alpha': 1.8582914036733394e-06}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:48:38,947] Trial 54 finished with value: 0.9092882881252005 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 784, 'learning_rate': 0.014646959409087973, 'gamma': 0.10874636934980603, 'subsample': 0.5483865391066379, 'colsample_bytree': 0.5985192194801012, 'max_depth': 15, 'min_child_weight': 7, 'reg_lambda': 8.758858244389235e-09, 'reg_alpha': 0.06542163558543655}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:50:13,415] Trial 55 finished with value: 0.9085658027942289 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 967, 'learning_rate': 0.010652246275151496, 'gamma': 0.3629297648568883, 'subsample': 0.3556209265331396, 'colsample_bytree': 0.4068487227078592, 'max_depth': 16, 'min_child_weight': 4, 'reg_lambda': 2.0426975522818787e-09, 'reg_alpha': 0.00286604387760383}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:51:40,459] Trial 56 finished with value: 0.9091438838936133 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 899, 'learning_rate': 0.01871878550991288, 'gamma': 0.1959120161334475, 'subsample': 0.3530209955183941, 'colsample_bytree': 0.44980068669231815, 'max_depth': 16, 'min_child_weight': 4, 'reg_lambda': 3.68150792791091e-08, 'reg_alpha': 0.004691231317923125}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:52:49,156] Trial 57 finished with value: 0.9089029084618281 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 776, 'learning_rate': 0.019909900363064097, 'gamma': 0.13207246371484088, 'subsample': 0.38185545268862037, 'colsample_bytree': 0.4566912206694946, 'max_depth': 16, 'min_child_weight': 4, 'reg_lambda': 6.2012522381347515e-09, 'reg_alpha': 0.8490746128968465}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:53:27,040] Trial 58 finished with value: 0.904470949498438 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 613, 'learning_rate': 0.022751882588788904, 'gamma': 0.10648090948986129, 'subsample': 0.3905908383338706, 'colsample_bytree': 0.4278170946222692, 'max_depth': 14, 'min_child_weight': 5, 'reg_lambda': 4.18140000703361e-08, 'reg_alpha': 4.028047167463128}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:54:53,227] Trial 59 finished with value: 0.9053861594740734 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 905, 'learning_rate': 0.038452783786658694, 'gamma': 0.044377548252913235, 'subsample': 0.4356291099969577, 'colsample_bytree': 0.4667528333757137, 'max_depth': 13, 'min_child_weight': 3, 'reg_lambda': 2.1059450596120888e-09, 'reg_alpha': 0.0010811857787070872}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:56:09,081] Trial 60 finished with value: 0.9055787564711523 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 877, 'learning_rate': 0.047054963537220024, 'gamma': 0.3364296453243424, 'subsample': 0.6108060183401507, 'colsample_bytree': 0.9897358730838155, 'max_depth': 8, 'min_child_weight': 7, 'reg_lambda': 1.4400038014503373e-09, 'reg_alpha': 0.00012379552202513002}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:57:42,022] Trial 61 finished with value: 0.9088547969266175 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 978, 'learning_rate': 0.015478247028510266, 'gamma': 0.3331998980252982, 'subsample': 0.5647670057892646, 'colsample_bytree': 0.39800243157491866, 'max_depth': 15, 'min_child_weight': 5, 'reg_lambda': 3.207148110815341e-07, 'reg_alpha': 1.8182832560061023e-05}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 08:59:02,894] Trial 62 finished with value: 0.9091437794546803 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 839, 'learning_rate': 0.015637472884781227, 'gamma': 0.1503010968763244, 'subsample': 0.30127472363909535, 'colsample_bytree': 0.4761605493196701, 'max_depth': 16, 'min_child_weight': 4, 'reg_lambda': 0.0006649658899551212, 'reg_alpha': 0.07312956643272336}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 09:00:32,162] Trial 63 finished with value: 0.9083247577364879 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 944, 'learning_rate': 0.017237012918694717, 'gamma': 0.13563670417138288, 'subsample': 0.32433659898105965, 'colsample_bytree': 0.5508282049800608, 'max_depth': 15, 'min_child_weight': 4, 'reg_lambda': 0.22070487144577644, 'reg_alpha': 0.012119659127134972}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 09:02:26,370] Trial 64 finished with value: 0.9079876288602369 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 615, 'learning_rate': 0.024733625339351164, 'gamma': 0.12066320499850637, 'subsample': 0.6480643554168624, 'colsample_bytree': 0.6696673195520844, 'max_depth': 15, 'min_child_weight': 6, 'reg_lambda': 9.224389330296644e-08, 'reg_alpha': 0.6426269489516183}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 09:04:38,146] Trial 65 finished with value: 0.9092882997295264 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 889, 'learning_rate': 0.01469870148609853, 'gamma': 0.037045628709126616, 'subsample': 0.33468586694110736, 'colsample_bytree': 0.5164717623426803, 'max_depth': 15, 'min_child_weight': 7, 'reg_lambda': 1.883086598485488e-08, 'reg_alpha': 0.0008508665243038652}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 09:05:50,147] Trial 66 finished with value: 0.9083248273624435 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 936, 'learning_rate': 0.010148309658342273, 'gamma': 0.4178153084363588, 'subsample': 0.32098167024195573, 'colsample_bytree': 0.5348321443476671, 'max_depth': 12, 'min_child_weight': 7, 'reg_lambda': 2.032464893011528e-08, 'reg_alpha': 0.061929947742644445}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 09:06:49,487] Trial 67 finished with value: 0.907891150494646 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 957, 'learning_rate': 0.03849127056127293, 'gamma': 0.2830441013895654, 'subsample': 0.34164711940599335, 'colsample_bytree': 0.6003434573594002, 'max_depth': 14, 'min_child_weight': 4, 'reg_lambda': 2.0606968968542002e-05, 'reg_alpha': 1.354861012363095}. Best is trial 41 with value: 0.9093365040993442.
# [I 2024-02-26 09:09:28,548] Trial 68 finished with value: 0.9095292403483339 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 964, 'learning_rate': 0.01451609112964774, 'gamma': 0.027824216273299604, 'subsample': 0.39334215360893243, 'colsample_bytree': 0.4547528701876042, 'max_depth': 14, 'min_child_weight': 7, 'reg_lambda': 4.168641020387065e-06, 'reg_alpha': 0.0003702915953803531}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:11:18,094] Trial 69 finished with value: 0.9069759289146846 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 840, 'learning_rate': 0.032362251703463074, 'gamma': 0.06261641463198153, 'subsample': 0.3335633175889236, 'colsample_bytree': 0.5239764909583632, 'max_depth': 14, 'min_child_weight': 6, 'reg_lambda': 0.00025452632142856403, 'reg_alpha': 1.5389370143521817e-07}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:13:11,924] Trial 70 finished with value: 0.9089029664834577 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 808, 'learning_rate': 0.022810626613323785, 'gamma': 0.14039362451488813, 'subsample': 0.39107575010977447, 'colsample_bytree': 0.3496632238598285, 'max_depth': 14, 'min_child_weight': 7, 'reg_lambda': 3.572250688839024e-09, 'reg_alpha': 1.4598617922043487e-05}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:14:22,581] Trial 71 finished with value: 0.908180341900575 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 793, 'learning_rate': 0.014620787641783876, 'gamma': 0.06876360767540342, 'subsample': 0.7098678816416483, 'colsample_bytree': 0.6364075963580368, 'max_depth': 12, 'min_child_weight': 7, 'reg_lambda': 5.194395471185062e-08, 'reg_alpha': 1.7609328127125063}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:16:35,344] Trial 72 finished with value: 0.9082766810142552 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 995, 'learning_rate': 0.018767170009357168, 'gamma': 0.06382824186335904, 'subsample': 0.3440752760682449, 'colsample_bytree': 0.5815828243243888, 'max_depth': 16, 'min_child_weight': 7, 'reg_lambda': 1.2601086252863734e-07, 'reg_alpha': 0.0002225721200449556}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:17:38,971] Trial 73 finished with value: 0.9084694056589193 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 559, 'learning_rate': 0.025160712749002972, 'gamma': 0.449605011297209, 'subsample': 0.8443391678189491, 'colsample_bytree': 0.634975221507965, 'max_depth': 8, 'min_child_weight': 5, 'reg_lambda': 4.539436988946309e-09, 'reg_alpha': 0.005559094446796692}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:19:34,495] Trial 74 finished with value: 0.9087584926259151 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 875, 'learning_rate': 0.014725709622618181, 'gamma': 0.12210966462052367, 'subsample': 0.41996590177651016, 'colsample_bytree': 0.31283978944818125, 'max_depth': 15, 'min_child_weight': 2, 'reg_lambda': 0.00027608638503283465, 'reg_alpha': 0.0005244763036932255}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:20:42,300] Trial 75 finished with value: 0.9071204723981825 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 742, 'learning_rate': 0.05647294171097746, 'gamma': 0.31531511405403884, 'subsample': 0.6259659492830763, 'colsample_bytree': 0.568654127863804, 'max_depth': 9, 'min_child_weight': 7, 'reg_lambda': 1.1818280893492782e-08, 'reg_alpha': 1.0937438725653465e-06}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:22:58,409] Trial 76 finished with value: 0.9089510432056903 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 870, 'learning_rate': 0.01330650190535573, 'gamma': 0.37602939165366867, 'subsample': 0.5488352171925334, 'colsample_bytree': 0.6176073333765485, 'max_depth': 10, 'min_child_weight': 5, 'reg_lambda': 2.0547593062365008e-09, 'reg_alpha': 2.7505099355113283e-06}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:24:11,765] Trial 77 finished with value: 0.9078913361638605 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 922, 'learning_rate': 0.010641192719502252, 'gamma': 0.14295310836376424, 'subsample': 0.4018633100195891, 'colsample_bytree': 0.6960516305409113, 'max_depth': 10, 'min_child_weight': 7, 'reg_lambda': 1.893096944273063e-05, 'reg_alpha': 0.002810493020815288}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:24:45,524] Trial 78 finished with value: 0.8876099335814802 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 733, 'learning_rate': 0.016103318842773627, 'gamma': 0.20951181472214034, 'subsample': 0.5599111645536331, 'colsample_bytree': 0.34050907663544827, 'max_depth': 13, 'min_child_weight': 7, 'reg_lambda': 1.2966720969058065e-06, 'reg_alpha': 31.35955344777229}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:26:09,523] Trial 79 finished with value: 0.9080358216257288 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 713, 'learning_rate': 0.017535329656106633, 'gamma': 0.09107240128925673, 'subsample': 0.3031657466442029, 'colsample_bytree': 0.6081520681278563, 'max_depth': 9, 'min_child_weight': 6, 'reg_lambda': 2.2037888083910706e-09, 'reg_alpha': 0.01855806202030615}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:28:26,089] Trial 80 finished with value: 0.9072649810687027 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 815, 'learning_rate': 0.028070449599224646, 'gamma': 0.23652546570342273, 'subsample': 0.3606348034581435, 'colsample_bytree': 0.4656725055832968, 'max_depth': 16, 'min_child_weight': 3, 'reg_lambda': 6.135778571780524e-07, 'reg_alpha': 0.08952058313317741}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:31:06,458] Trial 81 finished with value: 0.9087583881869821 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 989, 'learning_rate': 0.01273024922590984, 'gamma': 0.3299946700287625, 'subsample': 0.603660927746959, 'colsample_bytree': 0.6354047663112982, 'max_depth': 10, 'min_child_weight': 5, 'reg_lambda': 4.0389011264437445e-08, 'reg_alpha': 1.44723146886678e-09}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:33:16,520] Trial 82 finished with value: 0.9072650622989841 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 927, 'learning_rate': 0.010326485647382942, 'gamma': 0.20338422496481257, 'subsample': 0.3032262868561171, 'colsample_bytree': 0.33445465038250316, 'max_depth': 15, 'min_child_weight': 7, 'reg_lambda': 0.007229284523269406, 'reg_alpha': 0.000421920892340915}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:35:25,771] Trial 83 finished with value: 0.9065423680901461 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 782, 'learning_rate': 0.035811451860169236, 'gamma': 0.014858503943373149, 'subsample': 0.6093510738099503, 'colsample_bytree': 0.6293894542205332, 'max_depth': 14, 'min_child_weight': 7, 'reg_lambda': 0.004247093264745258, 'reg_alpha': 0.0007529767376376158}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:37:26,778] Trial 84 finished with value: 0.9078431433983687 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 632, 'learning_rate': 0.011841364930463784, 'gamma': 0.032128330930538414, 'subsample': 0.39074641696274537, 'colsample_bytree': 0.5420343421508172, 'max_depth': 16, 'min_child_weight': 6, 'reg_lambda': 2.440392876958132e-09, 'reg_alpha': 0.18473376079108447}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:39:44,521] Trial 85 finished with value: 0.9087101838171641 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 971, 'learning_rate': 0.014888857451238633, 'gamma': 0.48534780293704705, 'subsample': 0.5190532869622667, 'colsample_bytree': 0.6339652036862051, 'max_depth': 11, 'min_child_weight': 5, 'reg_lambda': 4.593745758054504e-09, 'reg_alpha': 1.0076577753485465e-05}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:41:08,439] Trial 86 finished with value: 0.9091919606158463 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 913, 'learning_rate': 0.018053866303864637, 'gamma': 0.1568109081857619, 'subsample': 0.34501374419877573, 'colsample_bytree': 0.43318982925455124, 'max_depth': 13, 'min_child_weight': 4, 'reg_lambda': 1.936171774952153e-05, 'reg_alpha': 0.12325924097553602}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:42:06,018] Trial 87 finished with value: 0.9068314898701196 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 680, 'learning_rate': 0.03385145533522414, 'gamma': 0.27597403082263255, 'subsample': 0.3709057436717509, 'colsample_bytree': 0.5397428293283827, 'max_depth': 16, 'min_child_weight': 5, 'reg_lambda': 3.2309971997011343e-09, 'reg_alpha': 0.000978563025719718}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:43:58,198] Trial 88 finished with value: 0.907505968104814 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 996, 'learning_rate': 0.011586313565824733, 'gamma': 0.3192304297509672, 'subsample': 0.5612416071927109, 'colsample_bytree': 0.7863368791586518, 'max_depth': 8, 'min_child_weight': 7, 'reg_lambda': 5.768584022994299e-07, 'reg_alpha': 0.0006669045727761667}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:45:34,381] Trial 89 finished with value: 0.9059160245993143 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 878, 'learning_rate': 0.06041590245813551, 'gamma': 0.009549347159791086, 'subsample': 0.3724405698286902, 'colsample_bytree': 0.37797731548430924, 'max_depth': 12, 'min_child_weight': 7, 'reg_lambda': 0.0005002851458420108, 'reg_alpha': 0.0005322476724982635}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:48:42,807] Trial 90 finished with value: 0.9091438258719838 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 962, 'learning_rate': 0.01252274574417337, 'gamma': 0.04870411009459434, 'subsample': 0.47251287330004493, 'colsample_bytree': 0.4479078922156537, 'max_depth': 12, 'min_child_weight': 6, 'reg_lambda': 5.698736497081372e-06, 'reg_alpha': 0.005380437413216118}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:51:43,258] Trial 91 finished with value: 0.9092401649856641 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 818, 'learning_rate': 0.011314462058651905, 'gamma': 0.011434979414216048, 'subsample': 0.5165767132296234, 'colsample_bytree': 0.5566106204596, 'max_depth': 14, 'min_child_weight': 7, 'reg_lambda': 5.682556298500138e-05, 'reg_alpha': 0.00443714854857805}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:53:22,663] Trial 92 finished with value: 0.908565675146644 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 932, 'learning_rate': 0.013880465185887472, 'gamma': 0.10087534165959615, 'subsample': 0.5244887097738961, 'colsample_bytree': 0.573551426176829, 'max_depth': 7, 'min_child_weight': 5, 'reg_lambda': 0.1453130047146155, 'reg_alpha': 0.16773224763958408}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:54:31,169] Trial 93 finished with value: 0.9059160942252698 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 968, 'learning_rate': 0.010454217858790818, 'gamma': 0.12063082251725718, 'subsample': 0.35946285832735997, 'colsample_bytree': 0.5011082845778793, 'max_depth': 9, 'min_child_weight': 3, 'reg_lambda': 7.341441632183425e-07, 'reg_alpha': 2.458382854174564}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:55:36,261] Trial 94 finished with value: 0.908421259310731 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 815, 'learning_rate': 0.02473231538859221, 'gamma': 0.11968162422837854, 'subsample': 0.3144736124386648, 'colsample_bytree': 0.36568280074659787, 'max_depth': 15, 'min_child_weight': 4, 'reg_lambda': 5.766229974213887e-05, 'reg_alpha': 0.8616990845123069}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 09:58:52,829] Trial 95 finished with value: 0.9087102186301419 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 975, 'learning_rate': 0.015966600576485673, 'gamma': 0.10178181232182838, 'subsample': 0.42408710744113065, 'colsample_bytree': 0.385719217887008, 'max_depth': 12, 'min_child_weight': 4, 'reg_lambda': 4.285492250527336e-07, 'reg_alpha': 0.013971102162790973}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:01:46,658] Trial 96 finished with value: 0.9090474171323484 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 973, 'learning_rate': 0.01613999020209326, 'gamma': 0.105254575953091, 'subsample': 0.5364458825749872, 'colsample_bytree': 0.5484082852211021, 'max_depth': 14, 'min_child_weight': 7, 'reg_lambda': 0.00025323180460208854, 'reg_alpha': 0.006824410758242351}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:02:17,610] Trial 97 finished with value: 0.902399484489426 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 655, 'learning_rate': 0.013884526433755096, 'gamma': 0.33294112993743114, 'subsample': 0.5750017994775956, 'colsample_bytree': 0.7233664207853001, 'max_depth': 4, 'min_child_weight': 5, 'reg_lambda': 3.2041987993505588e-09, 'reg_alpha': 0.0202403066810661}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:04:28,721] Trial 98 finished with value: 0.9091920302418017 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 607, 'learning_rate': 0.015186343118854095, 'gamma': 0.07602479896757743, 'subsample': 0.5147007870335595, 'colsample_bytree': 0.4254972863767553, 'max_depth': 11, 'min_child_weight': 5, 'reg_lambda': 0.0004948681667803267, 'reg_alpha': 0.0949579340954913}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:05:19,420] Trial 99 finished with value: 0.9073612737650792 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 479, 'learning_rate': 0.048915897133640224, 'gamma': 0.18862490516542468, 'subsample': 0.32273369373246985, 'colsample_bytree': 0.4256928655094376, 'max_depth': 8, 'min_child_weight': 4, 'reg_lambda': 0.213470964896061, 'reg_alpha': 0.4394993639120992}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:06:59,982] Trial 100 finished with value: 0.9080358448343807 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 804, 'learning_rate': 0.013759432296076754, 'gamma': 0.004884768441279157, 'subsample': 0.447589851749228, 'colsample_bytree': 0.6213680778836299, 'max_depth': 8, 'min_child_weight': 7, 'reg_lambda': 4.2944583944710004e-05, 'reg_alpha': 1.645743045831695e-06}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:10:36,546] Trial 101 finished with value: 0.9080358680430326 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 742, 'learning_rate': 0.010231700064608213, 'gamma': 0.0044864536660199905, 'subsample': 0.7248439906929058, 'colsample_bytree': 0.479171320889483, 'max_depth': 13, 'min_child_weight': 5, 'reg_lambda': 2.4830486405165373e-05, 'reg_alpha': 0.30914863935684755}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:13:19,577] Trial 102 finished with value: 0.9082767506402106 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 695, 'learning_rate': 0.010775578524230636, 'gamma': 0.04161983774057386, 'subsample': 0.5019086941478129, 'colsample_bytree': 0.4941650338596596, 'max_depth': 15, 'min_child_weight': 7, 'reg_lambda': 4.425444394037774e-05, 'reg_alpha': 7.257572285467021e-05}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:14:48,430] Trial 103 finished with value: 0.9080357519997735 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 949, 'learning_rate': 0.021200637232695316, 'gamma': 0.14611426183944848, 'subsample': 0.3410378614361379, 'colsample_bytree': 0.4965688950057391, 'max_depth': 14, 'min_child_weight': 4, 'reg_lambda': 1.2211502471930592e-06, 'reg_alpha': 3.1020740814344586e-05}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:16:09,111] Trial 104 finished with value: 0.9069759753319883 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 855, 'learning_rate': 0.020246401500107623, 'gamma': 0.03841906150511939, 'subsample': 0.4329371463940392, 'colsample_bytree': 0.4948950549345947, 'max_depth': 15, 'min_child_weight': 7, 'reg_lambda': 1.338410784027714e-05, 'reg_alpha': 3.6987784235521746}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:19:52,991] Trial 105 finished with value: 0.9087101838171641 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 976, 'learning_rate': 0.013397035880644052, 'gamma': 0.00498910486879231, 'subsample': 0.5687071278512756, 'colsample_bytree': 0.4721838735812283, 'max_depth': 13, 'min_child_weight': 6, 'reg_lambda': 1.2177888786202665e-06, 'reg_alpha': 9.078087023077543e-06}. Best is trial 68 with value: 0.9095292403483339.
# [I 2024-02-26 10:21:44,964] Trial 106 finished with value: 0.9092402462159453 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 575, 'learning_rate': 0.018846624799632474, 'gamma': 0.0921182237837681, 'subsample': 0.6337516479482955, 'colsample_bytree': 0.34846592131888143, 'max_depth': 10, 'min_child_weight': 5, 'reg_lambda': 0.004226378172289901, 'reg_alpha': 0.3356375852555565}. Best is trial 68 with value: 0.9095292403483339.
# ...
# [I 2024-02-26 10:33:30,479] Trial 116 finished with value: 0.9082285810833705 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 614, 'learning_rate': 0.022369380358319764, 'gamma': 0.018881283912251107, 'subsample': 0.426733945956315, 'colsample_bytree': 0.4269922002373531, 'max_depth': 12, 'min_child_weight': 4, 'reg_lambda': 0.000566192190425517, 'reg_alpha': 0.005839336755314053}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:34:40,403] Trial 117 finished with value: 0.9083247461321621 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 917, 'learning_rate': 0.02584957526455194, 'gamma': 0.18077221566253593, 'subsample': 0.6349443435647923, 'colsample_bytree': 0.3668591558946615, 'max_depth': 9, 'min_child_weight': 5, 'reg_lambda': 0.03879656194660584, 'reg_alpha': 0.15197203700577414}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:36:19,775] Trial 118 finished with value: 0.9076022608011906 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 640, 'learning_rate': 0.013874889202823173, 'gamma': 0.1471584473326632, 'subsample': 0.472584454856679, 'colsample_bytree': 0.34940332423242376, 'max_depth': 14, 'min_child_weight': 6, 'reg_lambda': 3.2555261922205663, 'reg_alpha': 0.405221866558826}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:37:23,377] Trial 119 finished with value: 0.9077467810760366 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 713, 'learning_rate': 0.013253408103838477, 'gamma': 0.29576677307393856, 'subsample': 0.7203027226524081, 'colsample_bytree': 0.6829922854184011, 'max_depth': 10, 'min_child_weight': 6, 'reg_lambda': 6.6404113987690285e-09, 'reg_alpha': 3.016983191706842e-07}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:39:49,458] Trial 120 finished with value: 0.908373066545239 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 999, 'learning_rate': 0.010672622440525406, 'gamma': 0.11162951285722886, 'subsample': 0.310079088700216, 'colsample_bytree': 0.33534230484676714, 'max_depth': 14, 'min_child_weight': 7, 'reg_lambda': 7.364455078739873e-07, 'reg_alpha': 2.93372016278898e-05}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:41:21,050] Trial 121 finished with value: 0.9057716899936826 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 676, 'learning_rate': 0.010011731345961231, 'gamma': 0.2977194027297695, 'subsample': 0.4765907100085182, 'colsample_bytree': 0.7094049388492908, 'max_depth': 9, 'min_child_weight': 7, 'reg_lambda': 2.1136575387881218e-08, 'reg_alpha': 0.0011280878084953456}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:42:36,956] Trial 122 finished with value: 0.9074577521306703 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 741, 'learning_rate': 0.010625684146880122, 'gamma': 0.17759781472894448, 'subsample': 0.4950822386533935, 'colsample_bytree': 0.5773674797075118, 'max_depth': 16, 'min_child_weight': 5, 'reg_lambda': 0.009264113881054453, 'reg_alpha': 0.5759671806764517}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:44:26,122] Trial 123 finished with value: 0.9082284534357855 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 667, 'learning_rate': 0.039537454321939475, 'gamma': 0.12917281249954998, 'subsample': 0.653467849029224, 'colsample_bytree': 0.5050046644849928, 'max_depth': 14, 'min_child_weight': 7, 'reg_lambda': 1.4627340282036945e-09, 'reg_alpha': 0.025839708424772366}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:45:44,084] Trial 124 finished with value: 0.9079876984861925 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 961, 'learning_rate': 0.02312766589517932, 'gamma': 0.1908526751965595, 'subsample': 0.30196021053997174, 'colsample_bytree': 0.3542788831045928, 'max_depth': 16, 'min_child_weight': 5, 'reg_lambda': 3.975590564288281e-06, 'reg_alpha': 0.00045944607960625954}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:46:36,498] Trial 125 finished with value: 0.9076505115883119 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 550, 'learning_rate': 0.024983390093772217, 'gamma': 0.1974895344175563, 'subsample': 0.6305570298718922, 'colsample_bytree': 0.30107196409532677, 'max_depth': 11, 'min_child_weight': 4, 'reg_lambda': 3.4092013313741605e-06, 'reg_alpha': 3.72320811355325}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:48:20,574] Trial 126 finished with value: 0.9066386723908485 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 761, 'learning_rate': 0.023134467343082044, 'gamma': 0.16187231799144192, 'subsample': 0.6528810597513225, 'colsample_bytree': 0.8544469447016347, 'max_depth': 9, 'min_child_weight': 6, 'reg_lambda': 2.962842024637238e-09, 'reg_alpha': 8.235208178032627e-08}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:49:23,558] Trial 127 finished with value: 0.9084693824502674 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 509, 'learning_rate': 0.012802249256423022, 'gamma': 0.11468377730375834, 'subsample': 0.36547208609382686, 'colsample_bytree': 0.5540782014701966, 'max_depth': 14, 'min_child_weight': 3, 'reg_lambda': 0.001582315052866001, 'reg_alpha': 0.000311707387597219}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:50:22,822] Trial 128 finished with value: 0.9081321955523869 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 706, 'learning_rate': 0.018923782691213274, 'gamma': 0.10189141673544766, 'subsample': 0.49776239332481026, 'colsample_bytree': 0.3863937483050391, 'max_depth': 6, 'min_child_weight': 4, 'reg_lambda': 6.949832320920086e-05, 'reg_alpha': 0.7878843566719216}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:51:19,517] Trial 129 finished with value: 0.9089992475755082 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 377, 'learning_rate': 0.05597060169439664, 'gamma': 0.09841713836012386, 'subsample': 0.6922072949695065, 'colsample_bytree': 0.3592713473476819, 'max_depth': 12, 'min_child_weight': 4, 'reg_lambda': 0.03259890084792634, 'reg_alpha': 1.641519063637832}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:52:41,643] Trial 130 finished with value: 0.9025918958172904 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 794, 'learning_rate': 0.08486423636820464, 'gamma': 0.15863726696822517, 'subsample': 0.44694664651268906, 'colsample_bytree': 0.6730370430937405, 'max_depth': 14, 'min_child_weight': 6, 'reg_lambda': 6.0663540395908716e-09, 'reg_alpha': 0.00013232067715740858}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:53:25,951] Trial 131 finished with value: 0.9050009422712637 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 558, 'learning_rate': 0.011293769231958949, 'gamma': 0.06771916173671366, 'subsample': 0.5939750819031132, 'colsample_bytree': 0.3341628503387419, 'max_depth': 9, 'min_child_weight': 5, 'reg_lambda': 4.658064518342312, 'reg_alpha': 1.0950610611726797}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:54:07,460] Trial 132 finished with value: 0.9082765301580185 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 485, 'learning_rate': 0.036666184718183184, 'gamma': 0.31427728440014724, 'subsample': 0.3338025322761218, 'colsample_bytree': 0.3234142178138009, 'max_depth': 13, 'min_child_weight': 3, 'reg_lambda': 1.0553530348432883e-08, 'reg_alpha': 0.09019397214473628}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:55:19,492] Trial 133 finished with value: 0.9082285810833707 and parameters: {'grow_policy': 'depthwise', 'n_estimators': 670, 'learning_rate': 0.010508718472396596, 'gamma': 0.34742162114240793, 'subsample': 0.3918358986018639, 'colsample_bytree': 0.431182906173039, 'max_depth': 15, 'min_child_weight': 4, 'reg_lambda': 2.244801994102176e-09, 'reg_alpha': 0.00010903779314730027}. Best is trial 109 with value: 0.9096737606231802.
# [I 2024-02-26 10:58:00,846] Trial 134 finished with value: 0.9097218605540647 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 788, 'learning_rate': 0.012530705265797653, 'gamma': 0.053110653084654125, 'subsample': 0.5111062261739988, 'colsample_bytree': 0.4691472396200357, 'max_depth': 13, 'min_child_weight': 7, 'reg_lambda': 1.6128154434988802e-06, 'reg_alpha': 0.006083506936061284}. Best is trial 134 with value: 0.9097218605540647.
# [I 2024-02-26 11:00:27,237] Trial 135 finished with value: 0.909770146154164 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 765, 'learning_rate': 0.01838214450298621, 'gamma': 0.061323782313901426, 'subsample': 0.6173117368877042, 'colsample_bytree': 0.33285037232496795, 'max_depth': 11, 'min_child_weight': 7, 'reg_lambda': 9.519119079026137e-07, 'reg_alpha': 0.0050221971838310545}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:01:59,577] Trial 136 finished with value: 0.908854738904988 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 865, 'learning_rate': 0.025879786367026467, 'gamma': 0.00200376731991031, 'subsample': 0.5889253198783826, 'colsample_bytree': 0.5133959182100973, 'max_depth': 7, 'min_child_weight': 5, 'reg_lambda': 2.9201993556370263e-06, 'reg_alpha': 0.14909261411339791}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:03:23,125] Trial 137 finished with value: 0.9089993288057896 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 490, 'learning_rate': 0.019570222828663893, 'gamma': 0.18312959796277758, 'subsample': 0.7211035941861147, 'colsample_bytree': 0.3737494195785768, 'max_depth': 10, 'min_child_weight': 6, 'reg_lambda': 0.010144966273410388, 'reg_alpha': 0.7205650109295838}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:05:42,967] Trial 138 finished with value: 0.9092402114029678 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 951, 'learning_rate': 0.010044199958277072, 'gamma': 0.12451314173306344, 'subsample': 0.5007493754726989, 'colsample_bytree': 0.46689272499078227, 'max_depth': 9, 'min_child_weight': 6, 'reg_lambda': 0.0001474282756568909, 'reg_alpha': 0.2192236179872694}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:07:04,686] Trial 139 finished with value: 0.9079876288602371 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 625, 'learning_rate': 0.023855040804339013, 'gamma': 0.0067028469204446495, 'subsample': 0.31119182095814796, 'colsample_bytree': 0.34679476509206564, 'max_depth': 10, 'min_child_weight': 7, 'reg_lambda': 4.07309007073547e-08, 'reg_alpha': 0.0005959920191687202}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:09:32,478] Trial 140 finished with value: 0.9083730781495649 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 612, 'learning_rate': 0.032986096575921546, 'gamma': 0.044832101611410186, 'subsample': 0.6741028572599699, 'colsample_bytree': 0.3448150549725817, 'max_depth': 14, 'min_child_weight': 5, 'reg_lambda': 2.7490596536894783e-08, 'reg_alpha': 0.0005157275132982277}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:11:20,227] Trial 141 finished with value: 0.909191983824498 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 718, 'learning_rate': 0.02132251651354396, 'gamma': 0.18532150987094248, 'subsample': 0.6715003287524101, 'colsample_bytree': 0.4557100278736187, 'max_depth': 9, 'min_child_weight': 6, 'reg_lambda': 3.0293467781007127e-06, 'reg_alpha': 1.4479853103764389e-05}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:14:09,452] Trial 142 finished with value: 0.9087101838171641 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 719, 'learning_rate': 0.015504863680274794, 'gamma': 0.12287751729387467, 'subsample': 0.8404268823590147, 'colsample_bytree': 0.440192671383547, 'max_depth': 12, 'min_child_weight': 7, 'reg_lambda': 0.00012466464876348737, 'reg_alpha': 2.705847685318376e-05}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:16:13,554] Trial 143 finished with value: 0.9093846620518583 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 943, 'learning_rate': 0.016327728290337108, 'gamma': 0.2175744894282584, 'subsample': 0.6275249447392738, 'colsample_bytree': 0.3809366230207648, 'max_depth': 9, 'min_child_weight': 6, 'reg_lambda': 7.33323021000271e-06, 'reg_alpha': 0.5482495397106449}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:17:36,438] Trial 144 finished with value: 0.9078914289984679 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 644, 'learning_rate': 0.011223264109418781, 'gamma': 0.23192933812282904, 'subsample': 0.7233444058466187, 'colsample_bytree': 0.30329544382628204, 'max_depth': 7, 'min_child_weight': 6, 'reg_lambda': 3.8159477051638655e-07, 'reg_alpha': 0.01595732738106484}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:18:31,278] Trial 145 finished with value: 0.8968593820278699 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 742, 'learning_rate': 0.010373662776143783, 'gamma': 0.07453266523461019, 'subsample': 0.6032776892898198, 'colsample_bytree': 0.6186386157818109, 'max_depth': 14, 'min_child_weight': 6, 'reg_lambda': 2.312194687418571e-09, 'reg_alpha': 15.722099243897116}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:19:51,797] Trial 146 finished with value: 0.9084210620371905 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 861, 'learning_rate': 0.023807790373907768, 'gamma': 0.22116709990426142, 'subsample': 0.3364068261702937, 'colsample_bytree': 0.575950323458847, 'max_depth': 8, 'min_child_weight': 6, 'reg_lambda': 2.6382315499295572e-05, 'reg_alpha': 0.6395788685908462}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:20:43,354] Trial 147 finished with value: 0.8979674442957544 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 988, 'learning_rate': 0.014115400401651355, 'gamma': 0.16128111457318495, 'subsample': 0.44155035509806073, 'colsample_bytree': 0.466139545155075, 'max_depth': 10, 'min_child_weight': 6, 'reg_lambda': 0.0020391269364580574, 'reg_alpha': 14.68861135520262}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:22:49,636] Trial 148 finished with value: 0.9094810591871679 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 756, 'learning_rate': 0.02579697630933003, 'gamma': 0.1394657787959135, 'subsample': 0.679505208908601, 'colsample_bytree': 0.3200274686641438, 'max_depth': 11, 'min_child_weight': 7, 'reg_lambda': 5.0174990604783186e-08, 'reg_alpha': 0.013380109622688811}. Best is trial 135 with value: 0.909770146154164.
# [I 2024-02-26 11:25:15,422] Trial 149 finished with value: 0.9080838403263323 and parameters: {'grow_policy': 'lossguide', 'n_estimators': 962, 'learning_rate': 0.029824320718316054, 'gamma': 0.09401340705311464, 'subsample': 0.7214369006696025, 'colsample_bytree': 0.4292218792414926, 'max_depth': 10, 'min_child_weight': 6, 'reg_lambda': 1.0275731335812698e-08, 'reg_alpha': 0.06781478236073407}. Best is trial 135 with value: 0.909770146154164.
# best optmized accuracy: 0.90977
# best hyperparameters: {'grow_policy': 'lossguide', 'n_estimators': 765, 'learning_rate': 0.01838214450298621, 'gamma': 0.061323782313901426, 'subsample': 0.6173117368877042, 'colsample_bytree': 0.33285037232496795, 'max_depth': 11, 'min_child_weight': 7, 'reg_lambda': 9.519119079026137e-07, 'reg_alpha': 0.0050221971838310545}

# %% [markdown]
# ### 4.4 Re-train on all data

# %% [markdown]
# Once we obtained the best parameters, we re-train on all our available data

# %%
xgb = XGBClassifier(**best_cls_params)
xgb.fit(train, target_numeric)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.33285037232496795, device='cuda',
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.061323782313901426,
#               grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.01838214450298621,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=11, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=765, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)

# %% [markdown]
# The we proceed to inference, convert outputted numeric labels into strings and then save everything into a submission

# %% [markdown]
# ## 5.0 Explainability

# %% [markdown]
# To understand how the model actually works, the XGBoost model itself, represented by the booster, is used to calculate SHAP (SHapley Additive exPlanations) values for each feature in the training data. The feature names are extracted from the 'train' DataFrame, and a DMatrix 'Xd' is created to represent the training data in a format suitable for XGBoost. The SHAP values are obtained by predicting contributions to the predictions using the 'predict' method with 'pred_contribs=True'.

# %%
from xgboost import DMatrix

booster = xgb.get_booster()

feature_names = train.columns
Xd = DMatrix(train)

shap_values = booster.predict(Xd, pred_contribs=True)
preds = booster.predict(Xd)

# %% [markdown]
# then we create a summary plot visualizing the impact of different features on the model predictions. The shap.summary_plot function is employed to generate a violin plot, where each violin represents the distribution of SHAP values for a specific feature.

# %%
shap_values[:,0,:-1].shape
# Out:
# (20758, 37)

# %%
target_encoder.classes_
# Out:
# ['Insufficient_Weight',
#  'Normal_Weight',
#  'Overweight_Level_I',
#  'Overweight_Level_II',
#  'Obesity_Type_I',
#  'Obesity_Type_II',
#  'Obesity_Type_III']

# %%
train.shape
# Out:
# (20758, 37)

# %%
import shap
import matplotlib.pyplot as plt

for k, target_label in enumerate(target_encoder.classes_):
    print(f"VIOLIN PLOT REPRESENTING <{target_label}>")
    shap.summary_plot(shap_values[:,k, :-1], train.values,
                      plot_type="violin",
                      feature_names=feature_names, show=False)
    plt.xticks(fontsize=8)
    plt.yticks(fontsize=8)
    plt.show()
    print()
# Out:
# VIOLIN PLOT REPRESENTING <Insufficient_Weight>
# VIOLIN PLOT REPRESENTING <Normal_Weight>
# VIOLIN PLOT REPRESENTING <Overweight_Level_I>
# VIOLIN PLOT REPRESENTING <Overweight_Level_II>
# VIOLIN PLOT REPRESENTING <Obesity_Type_I>
# VIOLIN PLOT REPRESENTING <Obesity_Type_II>
# VIOLIN PLOT REPRESENTING <Obesity_Type_III>

# %% [markdown]
# ## 6.0 Preparation of the submission

# %%
preds = xgb.predict(test)
labelled_preds = target_encoder.inverse_transform(preds)

# %%
submission = pd.read_csv("/kaggle/input/playground-series-s4e2/sample_submission.csv")
submission["NObeyesdad"] = labelled_preds.values
submission.to_csv("xgb_submission.csv", index=False)

# %%
submission.head(5)
# Out:
#       id          NObeyesdad
# 0  20758     Obesity_Type_II
# 1  20759  Overweight_Level_I
# 2  20760    Obesity_Type_III
# 3  20761      Obesity_Type_I
# 4  20762    Obesity_Type_III

# %% [markdown]
# ## 7.0 Submission strategies

# %% [markdown]
# Now that our single model submission is ready, let's prepare an ensembled one with multiout XGBoost and LightGBM and check if it improves our results as we figured after error analysis.

# %%
from copy import copy

multi_cls_params = copy(best_cls_params)
multi_cls_params["device"] = "cpu"
multi_cls_params["tree_method"] = "hist"
multi_cls_params["multi_strategy"] = "multi_output_tree"

# %%
multi = XGBClassifier(**multi_cls_params)
multi.fit(train, target_numeric)

lgb = LGBMClassifier(boosting_type="gbdt",
                     objective="multiclass",
                     metric="multi_logloss",
                     num_class=7,
                     learning_rate=0.025,
                     n_estimators=500,
                     lambda_l1=0.06,
                     lambda_l2=0.3,
                     max_depth=9,
                     colsample_bytree=0.40,
                     subsample=0.85,
                     min_child_samples=15,
                     verbosity=-1)

lgb.fit(train, target_numeric)

xgb_preds = xgb.predict_proba(test)
lgb_preds = lgb.predict_proba(test)
multixgb_preds = multi.predict_proba(test)

blended_preds = np.argmax((xgb_preds + lgb_preds + multixgb_preds), axis=1).ravel()
labelled_blended_preds = target_encoder.inverse_transform(blended_preds)

submission = pd.read_csv("/kaggle/input/playground-series-s4e2/sample_submission.csv")
submission["NObeyesdad"] = labelled_blended_preds.values
submission.to_csv("blended_submission.csv", index=False)

# %%
submission.head(5)
# Out:
#       id          NObeyesdad
# 0  20758     Obesity_Type_II
# 1  20759  Overweight_Level_I
# 2  20760    Obesity_Type_III
# 3  20761      Obesity_Type_I
# 4  20762    Obesity_Type_III

# %% [markdown]
# Another strategy is to bag ((Bootstrap Aggregating) multiple times your model and then blend the results. This should result in more stable results in the private leaderboard

# %%
from tqdm import tqdm

boots = 300

for k in tqdm(range(boots)):
    bootstrap_idx = np.random.choice(train.index, size=len(train), replace=True)

    xgb = XGBClassifier(**best_cls_params)
    xgb.fit(train.loc[bootstrap_idx], target_numeric.loc[bootstrap_idx])
    if k==0:
        preds = xgb.predict_proba(test)
    else:
        preds += xgb.predict_proba(test)
        
blended_preds = np.argmax(preds, axis=1).ravel()
labelled_blended_preds = target_encoder.inverse_transform(blended_preds)

submission = pd.read_csv("/kaggle/input/playground-series-s4e2/sample_submission.csv")
submission["NObeyesdad"] = labelled_blended_preds.values
submission.to_csv("bagged_submission.csv", index=False)
# Out:
# 100%|██████████| 300/300 [2:40:15<00:00, 32.05s/it]

# %%
submission.head(5)
# Out:
#       id          NObeyesdad
# 0  20758     Obesity_Type_II
# 1  20759  Overweight_Level_I
# 2  20760    Obesity_Type_III
# 3  20761      Obesity_Type_I
# 4  20762    Obesity_Type_III

# %% [markdown]
# Here we complete our overview of this multiclass problem. The next step in the competition is to feed the data we prepared to a auto-ml engine or build a blending or stacking solution that could bring you up the leaderboard. Good luck!
